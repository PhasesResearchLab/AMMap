# %% [markdown]
# #Additive Manufacturing Path Planning Made Effortless
#
# --> ***(This notebook is built up on the existing nimplex software and examples. Please see https://github.com/amkrajewski/nimplex for setting up and utilizing nimplex)***
#
# --> You will additionally need `pycalphad` and `pathfinding` libraries to run part of this exercise. If you are running this in Codespaces, it has been pre-installed for you.

# %% [markdown]
# **In this tutorial, we will demonstrate how effortless it is to dramatically speed up the exploration of feasible compositional spaces in high dimensional spaces through employing `nimplex`'s graph representations that abstract the underlying problem and dimensionality.**
#
# **We will also design several neat, mathematically optimal (given some criteria) paths in a 7-component chemical space connecting two alloys of interest by mixing 4 fixed-composition alloy powders to create a tetrahedral attainable/design space. The beauty of this approach is that at no point (except for plotting in 3D for "human consumption") will we explicitly consider the dimensionality or the distance as the connectivity between the points in the space has been abstracted into graph adjacency. If you wish to add another alloy to the design process, you add it to the list, and you are done :)**

# %%
# Import nimplex and some of its plotting utilities
import nimplex
from utils import plotting

# %%
# Python wrapper for Plotly library
import plotly.express as px
import pandas as pd
from pprint import pprint

# %% [markdown]
# ## Example
# Let's get back to our example (QuickStart) of the pair of **attainable space** simplex grid and corresponding **elemental space** positions defined for `7`-component elemental space of `Ti`, `Zr`, `Hf`, `W`, `Nb`, `Ta`, and `Mo` formed by `4` alloys:
# - Ti50 Zr50
# - Hf95 Ti5
# - Mo33 Nb33 Ta33
# - Mo10 Nb10 W80
#
# which we can represent as points in the elemental space:

# %%
elementalSpaceComponents = ['V', 'Ni', 'Cr', 'Fe']
attainableSpaceComponents = ['SS304L', 'NiCr', 'V', 'FE']
attainableSpaceComponentPositions = [[0, 0.096114519430,0.1993865031, 0.7044989775], [0, 80, 20, 0], [100, 0, 0, 0], [0, 0, 0, 100]]

# %% [markdown]
# And create tetrahedral grids with their compositions quantized at `12` divisions per dimension.

# %%
gridAtt, gridEl = nimplex.embeddedpair_simplex_grid_fractional_py(attainableSpaceComponentPositions, 12)

# %% [markdown]
# We used the **elemental**, or chemical, space to run the Root Mean Square Atomic Displacement (RMSAD) model by Tandoc (10.1038/s41524-023-00993-x) which acts as a lower-cost proxy for yield stress and hardness estimations in the absence of direct data:

# %% [markdown]
# import pqam_rmsadtandoc2023
# rmsadList = []
# for point in gridEl:
#     formula = ' '.join([f'{c}{p}' for c, p in zip(elementalSpaceComponents, point)])
#     rmsadList.append(pqam_rmsadtandoc2023.predict(formula))

# %% [markdown]
# And the **attainable** space grid to plot the results after projecting them to the Euclidean space:

# %%
# Hover approximate formula for each point
formulas = []
for i, comp in enumerate(gridEl):
    formulas.append(f"({i:>3}) "+"".join([f"{el}{100*v:.1f} " if v>0 else "" for el, v in zip(elementalSpaceComponents, comp)]))

# Generate the projected grid
gridAtt_projected_df = pd.DataFrame(plotting.simplex2cartesian_py(gridAtt), columns=['x','y','z'])

# Attach pure component (alloy) labels to corners
pureComponentIndices = nimplex.pure_component_indexes_py(4, 12)
labels = ['']*len(gridAtt_projected_df)
for comp, idx in zip(attainableSpaceComponents, pureComponentIndices):
    labels[idx] = "<b>"+comp+"</b>"

# %% [markdown]
# # Add text labels at the corners of the simplex
# px.scatter_3d(gridAtt_projected_df, x='x', y='y', z='z', color=rmsadList, text=labels, hover_name=formulas,
#               template='plotly_white', width=800, height=700,
#               labels={'color':'RMSAD', 'x':'', 'y':'', 'z':''})

# %% [markdown]
# ## Thermodynamic Equilibria
#
# **In this section we will be using `pycalphad` which is an amazing free open-source library for building thermodynamic models and performing calculations on them, including studying of phase equilibria, or what atomic arrangements are stable (coexist in equilibrium) at a given temperature and composition.** You can read more about `pycalphad` at [pycalphad.org](https://pycalphad.org/) and find an great tutorial at [this 2023 workshop materials repository](https://github.com/materialsgenomefoundation/2023-workshop-material/tree/main/pycalphad).
#
# Let's start by loading a database of thermodynamic properties which defines, among other things, the Gibbs energy of each phase as a function of temperature and composition. You can find many of such databases at [TDBDB](https://avdwgroup.engin.brown.edu) maintained by Axel van de Walle's group at Brown University.
#
# In this example, we will be using a TDB `CrHfMoNbTaTiVWZr_9element_Feb2023` placed for you in the `examples` directory, which is a 9-element database for the elements `Cr`, `Hf`, `Mo`, `Nb`, `Ta`, `Ti`, `V`, `W`, and `Zr`, being developed by Shuang Lin in our group (Phases Research Lab at PSU). This wersion is an older *work in progress* one that has not been published, so while it is perfect for tutorial like this one, please refrain from using it for any serious work.

# %%
from pycalphad import Database
dbf = Database("ammap/databases/Al-Cr-Fe-Ni-Ti-V_04-13.tdb")
phases = list(set(dbf.phases.keys()))
print(elementalSpaceComponents)
print(f'Loaded TDB file with phases considered: {phases}')
# Out:
# ['V', 'Ni', 'Cr', 'Fe']
# Loaded TDB file with phases considered: ['LAVES_A15', 'AL23V4', 'TS01T3', 'TAOA', 'AL45CR7', 'AL5TI2', 'LIQUID', 'AL5FE4', 'ALCU_ETA', 'LAVES_C15', 'BCC_B2', 'LAVES_C14', 'NI8V', 'AL2FE', 'BCC_A2', 'AL3TI_L', 'AL11CR4', 'AL4NI3', 'NITI2', 'ALTI3_D019', 'ALTI', 'AL4CR', 'AL23V4_194', 'SIGMA_D8B', 'AL5TI3', 'D82_217', 'ALCU_EPSILON', 'LAVES_C36', 'ALCU_ZETA', 'AL2TI', 'AL5FE2', 'AL3M', 'GAMMAL', 'ALCU_THETA', 'AL3NI2', 'TS01TI', 'ALCR2', 'AL21V2', 'L12_FCC', 'NIV3_A15', 'GAMMA_D83', 'AL45V7', 'ALCU_DELTA', 'AL45CR7_12', 'AL5CR', 'AL21V2_227', 'CRNI2', 'GAMMAH', 'HCP_A3', 'AL3NI1', 'AL13FE4', 'AL3NI5', 'NI3V_D022', 'FCC_A1', 'NI3TI', 'AL8V5', 'GAMMA_H']
# /opt/conda/lib/python3.11/site-packages/pycalphad/io/tdb.py:294: UserWarning:
#
# The type definition character `*` in `TYPE_DEFINITION * GES AMEND_PHASE_DESCRIPTION HCP_A3 MAGNETIC -3.0 2.80000E-01 ` is not used by any phase.

# %% [markdown]
# As you can see, we will be looking at several different phases here. To keep things as simple as possible, we can split them in three groups:
# - **liquid** phases: `LIQUID` (which we obviously want to avoid in a solid part design)
# - **solid solution** phases: `FCC_A1`, `BCC_A2`, and `HCP_A3`
# - **intermetallic** phases: `LAVES_C14`, `LAVES_C15`, and `LAVES_C36`
#
# Designing an alloy is a complex procedure but for the sake of this tutorial, we will be focusing on the most common issue which is the formation of intermetallic phases which cause embrittlement and reduce the ductility of the material. **Thus, we will apply a simple constraint that the alloy should only contain the solid solution phases FCC, BCC, and HCP.**
#
# **Now, knowing what we are looking for (phases at equilibrium), we can start by writing a short Python script around `pycalphad` to calculate the equilibrium phases for a given chemical elements composition `elP`. It is already placed in the `examples` directory as `myPycalphadCallable.py` which defines a function `equilibrium_callable` that takes a composition and returns the equilibrium phases.**
#
# **We will arbitrarily pick `1000K`** as the temperature for the sake of this tutorial, but you can change it to any other value you like. Or even make it a list and add phases present at each temperature to a set to apply our constraint over a range of temperatures.
#
#
# Please note that much more information is generated in the process (e.g., chemical composition of each phase and its fraction) but we are only interested in the phase presence. If you wish to do so, modifying the script to, e.g., allow for up to 5% of intermetallic phases, is a trivial task. Advanced users may also want to have a look at the `scheil_callable` we do not use in this tutorial for the sake of runtime, but which can be used to simulate solidification of the alloy from a liquid state in an additive manufacturing process.

# %%
from ammap.callables.EqScheil import equilibrium_callable, scheil_callable

# %% [markdown]
# Let's test it on some composition in our space starting with the first point!

# %%
print(formulas[121])
c=equilibrium_callable(gridEl[121])
# Out:
# (121) V58.3 Ni14.1 Cr5.0 Fe22.5

# %%
c
# Out:
# {'Phases': ['SIGMA_D8B', 'SIGMA_D8B'],
#  'PhaseFraction': [0.7401526482379205, 0.25984735109622004]}

# %% [markdown]
# You should see `['BCC_A2']` in a second or so if you've run it at the default `1000K`. Quick and neat, right? Now, let's pick some compositionally complex alloy that does not lay around the corner of the attainable space tetrahedron and presents an actual challenge.

# %%
print(formulas[63])
equilibrium_callable(gridEl[63])
# Out:
# ( 63) Ni40.0 Cr10.0 Fe50.0
# {'Phases': ['L12_FCC'],
#  'PhaseFraction': array([[[[[[[ 1., nan, nan, nan, nan]]]]]]])}

# %%
#scheil_callable(gridEl[63])

# %% [markdown]
# Now, you should have seen an example of infeasible point composed of `['HCP_A3', 'LAVES_C15', 'BCC_A2']`. Let's deploy this in parallel over all the points in the elemental space `gridEl` and see how it looks like! We will use the `process_map` function from the `tqdm` library to show a neat progress bar while the calculations are running in parallel. On the 4-core Codespaces VM you can expect it to take around 2-3 minutes.

# %%
from tqdm import tqdm
from tqdm.contrib.concurrent import process_map

# %%
gridPhases = process_map(equilibrium_callable, gridEl)
# Out:
#   0%|          | 0/455 [00:00<?, ?it/s]

# %%
#scheilPhases = process_map(scheil_callable,gridEl)

# %% [markdown]
# Let's see how some of the data looks like.

# %%
gridPhases[120:130]
# Out:
# [{'Phases': [], 'PhaseFraction': []},
#  {'Phases': ['SIGMA_D8B', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7401526482379205, 0.25984735109622004]},
#  {'Phases': ['SIGMA_D8B', 'SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.6461782277858971,
#    0.027165408426788717,
#    0.3266563640677085]},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.5831841387961331, 0.41681586107191304]},
#  {'Phases': ['L12_FCC'], 'PhaseFraction': [1.0000000000079763]},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.9697815004004096, 0.030218499605807886]},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.45697279565186455, 0.5430272043369339]},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.6718562366936901, 0.3281437633078831]},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7997002216958735,
#    0.14890062780280855,
#    0.05139915251767326]},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7818407890987, 0.2181592110755253]}]

# %%
infeasiblePhases = set([
    'AL3M', 'AL5FE2', 'LIQUID', 'AL11CR4', 'D82_217', 'AL3NI1', 'NI3TI', 'AL5FE4', 'TAOA', 'LAVES_C15', 'GAMMAH', 'AL5CR', 'AL2FE', 'AL4CR', 'NIV3_A15', 'GAMMA_H', 
    'ALTI3_D019', 'ALCU_DELTA', 'AL45CR7', 'TS01TI', 'NI8V', 'AL45CR7_12', 'LAVES_C14', 'LAVES_A15', 'AL3NI5', 'AL5TI3', 'ALCU_EPSILON', 'NITI2', 'AL8V5', 'ALCR2', 'AL23V4', 'AL13FE4', 
    'AL4NI3', 'ALCU_ZETA', 'ALCU_THETA', 'AL3NI2', 'AL23V4_194', 'CRNI2', 'NI3V_D022', 'LAVES_C36', 'TS01T3', 'AL21V2_227', 'AL5TI2', 'ALCU_ETA', 'GAMMAL', 
    'GAMMA_D83', 'SIGMA_D8B', 'AL21V2', 'AL2TI', 'AL3TI_L', 'ALTI', 'AL45V7'])

# %%
gridPhases
# Out:
# [{'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999540268],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999614034],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999975138],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.48211238203705525, 0.5178876182637987],
#   'infeasiblePhases': 0.5178876182637987},
#  {'Phases': ['SIGMA_D8B'],
#   'PhaseFraction': [1.000000000235801],
#   'infeasiblePhases': 1.000000000235801},
#  {'Phases': ['SIGMA_D8B'],
#   'PhaseFraction': [0.9999999980711901],
#   'infeasiblePhases': 0.9999999980711901},
#  {'Phases': ['SIGMA_D8B'],
#   'PhaseFraction': [0.9999999994533618],
#   'infeasiblePhases': 0.9999999994533618},
#  {'Phases': ['SIGMA_D8B'],
#   'PhaseFraction': [1.0000000005491791],
#   'infeasiblePhases': 1.0000000005491791},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.78275843247476, 0.2172415660881765],
#   'infeasiblePhases': 0.78275843247476},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000078066],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999921931],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999782705],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999221991],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000383957],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.9273770981023516, 0.07262290191168277],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000127143],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999996708],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.6240202500863844, 0.3759797497692812],
#   'infeasiblePhases': 0.3759797497692812},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.6558613458879932, 0.34413865410011785],
#   'infeasiblePhases': 0.6558613458879932},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.08985936701563531, 0.9101406326549852],
#   'infeasiblePhases': 0.9101406326549852},
#  {'Phases': ['SIGMA_D8B'],
#   'PhaseFraction': [1.0000000000071234],
#   'infeasiblePhases': 1.0000000000071234},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.83444804272173, 0.16555195845462511],
#   'infeasiblePhases': 0.83444804272173},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.78293165775552, 0.21706834255202642],
#   'infeasiblePhases': 0.21706834255202642},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9268297599964372, 0.07317024057008759],
#   'infeasiblePhases': 0.07317024057008759},
#  {'Phases': ['BCC_B2', 'NIV3_A15'],
#   'PhaseFraction': [0.892187134789693, 0.10781286512721447],
#   'infeasiblePhases': 0.10781286512721447},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999748723],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.4738763363174072, 0.5261236636915546],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.769817503827301, 0.23018249617081718],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.046924247119222134, 0.9530757528745901],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000109697],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000051916],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.6280264375051455, 0.3719735627102731],
#   'infeasiblePhases': 0.3719735627102731},
#  {'Phases': ['SIGMA_D8B', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8537292116942512, 0.14627078936293195],
#   'infeasiblePhases': 1.0000000010571832},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.16243488428547465, 0.8375651157866248],
#   'infeasiblePhases': 0.8375651157866248},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.581389747698241, 0.418610252558391],
#   'infeasiblePhases': 0.418610252558391},
#  {'Phases': ['BCC_B2', 'NIV3_A15'],
#   'PhaseFraction': [0.5918237121903664, 0.40817628768059117],
#   'infeasiblePhases': 0.40817628768059117},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999911336],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.9475436930661997, 0.05245630696066812],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.5207118178671423, 0.47928818212912366],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.6848383318708728, 0.3151616681322047],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.8493661534593392, 0.15063384654527565],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8622338564958802, 0.13776614348188795],
#   'infeasiblePhases': 0.13776614348188795},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.6574430248690595, 0.34255697516636624],
#   'infeasiblePhases': 0.34255697516636624},
#  {'Phases': ['SIGMA_D8B', 'SIGMA_D8B'],
#   'PhaseFraction': [0.5572094579172385, 0.44279054246294824],
#   'infeasiblePhases': 1.0000000003801868},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.83310892911667, 0.16689107073349896],
#   'infeasiblePhases': 0.83310892911667},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B', 'NIV3_A15'],
#   'PhaseFraction': [0.31776250094032227,
#    0.5677178564025291,
#    0.1145196420244679],
#   'infeasiblePhases': 0.682237498426997},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.000000000006834],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000000522],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.08398723851651468,
#    0.8195398528044906,
#    0.09647290869405052],
#   'infeasiblePhases': 0.09647290869405052},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.44416265768937785, 0.5558373423085256],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.34014172172481066,
#    0.5053636416877676,
#    0.1544946392232827],
#   'infeasiblePhases': 0.1544946392232827},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.348223289132486,
#    0.5239820948020336,
#    0.12779461725623398],
#   'infeasiblePhases': 0.348223289132486},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.6298810521261797, 0.37011894794150835],
#   'infeasiblePhases': 0.6298810521261797},
#  {'Phases': ['SIGMA_D8B', 'SIGMA_D8B'],
#   'PhaseFraction': [0.07191367431697676, 0.9280863257555653],
#   'infeasiblePhases': 1.000000000072542},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.016004176755044813, 0.983995824139881],
#   'infeasiblePhases': 0.983995824139881},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000213496],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000267906],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.86982455722096, 0.1301754426561935],
#   'infeasiblePhases': 0.1301754426561935},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7506964690588426, 0.24930353090156485],
#   'infeasiblePhases': 0.24930353090156485},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.13826140880670354,
#    0.34111272254261515,
#    0.5206258740225708],
#   'infeasiblePhases': 0.34111272254261515},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.546150563510953,
#    0.16874121565396594,
#    0.2851082229980249],
#   'infeasiblePhases': 0.546150563510953},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.08812944167816156,
#    0.03820672373371087,
#    0.8736638364593682],
#   'infeasiblePhases': 0.8736638364593682},
#  {'Phases': ['SIGMA_D8B'],
#   'PhaseFraction': [0.9999999987061531],
#   'infeasiblePhases': 0.9999999987061531},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.000000000020558],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999731671],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8668118167082892, 0.13318818324428053],
#   'infeasiblePhases': 0.13318818324428053},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7340856834027542, 0.26591431636112617],
#   'infeasiblePhases': 0.26591431636112617},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.43116070664075185, 0.5688392934768584],
#   'infeasiblePhases': 0.43116070664075185},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.6729422279019479, 0.32705777223115695],
#   'infeasiblePhases': 0.6729422279019479},
#  {'Phases': ['SIGMA_D8B'],
#   'PhaseFraction': [1.0000000003084504],
#   'infeasiblePhases': 1.0000000003084504},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000040503],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000034117],
#   'infeasiblePhases': 0},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.11675203979275284, 0.8832479600429589],
#   'infeasiblePhases': 0.11675203979275284},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.2639807827858766, 0.7360192172388401],
#   'infeasiblePhases': 0.2639807827858766},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.45090776966223767, 0.5490922301242559],
#   'infeasiblePhases': 0.45090776966223767},
#  {'Phases': ['SIGMA_D8B', 'CRNI2'],
#   'PhaseFraction': [0.7313721699182909, 0.2686278298772211],
#   'infeasiblePhases': 0.999999999795512},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999741812],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.000000000000707],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9323984855181042, 0.06760151473539718],
#   'infeasiblePhases': 0.06760151473539718},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.2260665581375523, 0.7739334419105838],
#   'infeasiblePhases': 0.2260665581375523},
#  {'Phases': ['SIGMA_D8B', 'NI3V_D022'],
#   'PhaseFraction': [0.5938584588447771, 0.40614154142192443],
#   'infeasiblePhases': 1.0000000002667015},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999713263],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999971853],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999883313],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8420775742209871, 0.157922425182895],
#   'infeasiblePhases': 0.157922425182895},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000137514],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999866374],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.000000000004583],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999279601],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.000000000031584],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000549094],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999922268],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999915448],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999839956],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.5600759196811923, 0.43992408075659123],
#   'infeasiblePhases': 0.43992408075659123},
#  {'Phases': ['SIGMA_D8B'],
#   'PhaseFraction': [0.9999999991543143],
#   'infeasiblePhases': 0.9999999991543143},
#  {'Phases': ['SIGMA_D8B'],
#   'PhaseFraction': [1.0000000000188636],
#   'infeasiblePhases': 1.0000000000188636},
#  {'Phases': ['SIGMA_D8B'],
#   'PhaseFraction': [0.9999999996050609],
#   'infeasiblePhases': 0.9999999996050609},
#  {'Phases': ['SIGMA_D8B'],
#   'PhaseFraction': [0.9999999994736114],
#   'infeasiblePhases': 0.9999999994736114},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.3864001787505197, 0.6135998220107566],
#   'infeasiblePhases': 0.6135998220107566},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.000000000002096],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000011358],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000130271],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000352915],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.8884485233183074, 0.11155147669761174],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999981254],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999993389],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999093686],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.5973355159643305, 0.4026644840452877],
#   'infeasiblePhases': 0.4026644840452877},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.6093348489874003, 0.390665151089406],
#   'infeasiblePhases': 0.6093348489874003},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.819961548853866, 0.18003845060751653],
#   'infeasiblePhases': 0.819961548853866},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.36277128168838646, 0.6372287188046822],
#   'infeasiblePhases': 0.6372287188046822},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.840895730422603, 0.15910426929238686],
#   'infeasiblePhases': 0.15910426929238686},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9051047344923551, 0.0948952653386856],
#   'infeasiblePhases': 0.0948952653386856},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999778506],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.568334254905049, 0.4316657451062851],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.2372636767890241, 0.7627363232286316],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.05534213229468371, 0.9446578676930819],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999953127],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999983109],
#   'infeasiblePhases': 0},
#  {'Phases': [], 'PhaseFraction': [], 'infeasiblePhases': 0},
#  {'Phases': ['SIGMA_D8B', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7401526482379205, 0.25984735109622004],
#   'infeasiblePhases': 0.9999999993341405},
#  {'Phases': ['SIGMA_D8B', 'SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.6461782277858971,
#    0.027165408426788717,
#    0.3266563640677085],
#   'infeasiblePhases': 0.6733436362126858},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.5831841387961331, 0.41681586107191304],
#   'infeasiblePhases': 0.41681586107191304},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000079763],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.9697815004004096, 0.030218499605807886],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.45697279565186455, 0.5430272043369339],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.6718562366936901, 0.3281437633078831],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7997002216958735,
#    0.14890062780280855,
#    0.05139915251767326],
#   'infeasiblePhases': 0.05139915251767326},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7818407890987, 0.2181592110755253],
#   'infeasiblePhases': 0.2181592110755253},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.40666081622131156, 0.593339183844579],
#   'infeasiblePhases': 0.40666081622131156},
#  {'Phases': ['SIGMA_D8B', 'SIGMA_D8B'],
#   'PhaseFraction': [0.44951177107456863, 0.5504882289323801],
#   'infeasiblePhases': 1.0000000000069487},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.7602318208721826, 0.23976817981135407],
#   'infeasiblePhases': 0.7602318208721826},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000130889],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9731108163126487, 0.0268891837679994],
#   'infeasiblePhases': 0.0268891837679994},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8410703607473159, 0.158929639190009],
#   'infeasiblePhases': 0.158929639190009},
#  {'Phases': ['L12_FCC', 'BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.5525175942551684,
#    0.2965691925981304,
#    0.1509132216978715],
#   'infeasiblePhases': 0.1509132216978715},
#  {'Phases': ['L12_FCC', 'BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.33204427148747667,
#    0.4308738928517092,
#    0.23708183953625006],
#   'infeasiblePhases': 0.23708183953625006},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.4297809469451704,
#    0.11542284364636721,
#    0.45479621157036465],
#   'infeasiblePhases': 0.4297809469451704},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.6937479162901958, 0.30625208347519756],
#   'infeasiblePhases': 0.6937479162901958},
#  {'Phases': ['SIGMA_D8B'],
#   'PhaseFraction': [1.000000000365971],
#   'infeasiblePhases': 1.000000000365971},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000090348],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.981604214324126, 0.01839578593857599],
#   'infeasiblePhases': 0.01839578593857599},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8319541403658005, 0.16804585976154188],
#   'infeasiblePhases': 0.16804585976154188},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7058165989167511, 0.29418340103025714],
#   'infeasiblePhases': 0.29418340103025714},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.42245324806626,
#    0.5182208297996125,
#    0.059325931885919794],
#   'infeasiblePhases': 0.42245324806626},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.622742744653505,
#    0.09923580394049214,
#    0.27802145542162565],
#   'infeasiblePhases': 0.622742744653505},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.9379907839523193,
#    0.03452321901521728,
#    0.027486005659242436],
#   'infeasiblePhases': 0.9379907839523193},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.000000000025722],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000031042],
#   'infeasiblePhases': 0},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.16711164149344895, 0.8328883582570858],
#   'infeasiblePhases': 0.16711164149344895},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.30695263828958774, 0.6930473619075038],
#   'infeasiblePhases': 0.30695263828958774},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.4782545452612432, 0.5217454547770706],
#   'infeasiblePhases': 0.4782545452612432},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.7294890359294788, 0.2705109644415677],
#   'infeasiblePhases': 0.7294890359294788},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.000000000018397],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999966416],
#   'infeasiblePhases': 0},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.144307310061799, 0.8556926897240592],
#   'infeasiblePhases': 0.144307310061799},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.2983272640126068, 0.7016727356992145],
#   'infeasiblePhases': 0.2983272640126068},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.5078303576631683, 0.49216964244003975],
#   'infeasiblePhases': 0.49216964244003975},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000198177],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999944346],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9131239615070493, 0.08687603871768582],
#   'infeasiblePhases': 0.08687603871768582},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.2519521486614764, 0.7480478512882835],
#   'infeasiblePhases': 0.2519521486614764},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.999999999999365],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000049634],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999963534],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999667186],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000131228],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000004468],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000008746],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.000000000011027],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999955622],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7640599881111918, 0.23594001166049047],
#   'infeasiblePhases': 0.23594001166049047},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.7959155772298919, 0.20408442728974796],
#   'infeasiblePhases': 0.7959155772298919},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.14192099815454778, 0.8580790006784565],
#   'infeasiblePhases': 0.8580790006784565},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.8497960738219331, 0.15020392618776934],
#   'infeasiblePhases': 0.8497960738219331},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.18094248857443168, 0.8190575115791833],
#   'infeasiblePhases': 0.8190575115791833},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.5951217854489551, 0.4048782137880912],
#   'infeasiblePhases': 0.4048782137880912},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000142957],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.000000000045908],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999726279],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.8477775611320207, 0.15222243885624967],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000000322],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000207767],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.000000000484763],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8380964740583099, 0.16190352620006593],
#   'infeasiblePhases': 0.16190352620006593},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.6603729839999775, 0.33962701582912297],
#   'infeasiblePhases': 0.33962701582912297},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.4070785734171722, 0.5929214265092921],
#   'infeasiblePhases': 0.5929214265092921},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.5434881217364682, 0.45651187816880495],
#   'infeasiblePhases': 0.45651187816880495},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8581295893003819, 0.1418704112046595],
#   'infeasiblePhases': 0.1418704112046595},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999750128],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.6062229133425244, 0.3937770866744837],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.24886887727990556, 0.7511311227181002],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.9320960570994232, 0.06790394289278048],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999643384],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9783354815666849, 0.021664518435687022],
#   'infeasiblePhases': 0.021664518435687022},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999904191],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B', 'SIGMA_D8B'],
#   'PhaseFraction': [0.11025702123845663,
#    0.5686760479789494,
#    0.32106693101251904],
#   'infeasiblePhases': 0.8897429789914685},
#  {'Phases': ['SIGMA_D8B', 'SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.507090511078541,
#    0.0037547967837485525,
#    0.48915469217939156],
#   'infeasiblePhases': 0.5108453078622895},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999983263],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9406493487299543, 0.059350651285867674],
#   'infeasiblePhases': 0.059350651285867674},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.3469105495801393,
#    0.5447911410852971,
#    0.10829830933484773],
#   'infeasiblePhases': 0.10829830933484773},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.34263214133910797, 0.6573678586517357],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7308268595463144,
#    0.1379637900854931,
#    0.13120935328514818],
#   'infeasiblePhases': 0.13120935328514818},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7065525539147779, 0.29344744630020114],
#   'infeasiblePhases': 0.29344744630020114},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.5276446370479775, 0.4723553629421699],
#   'infeasiblePhases': 0.4723553629421699},
#  {'Phases': ['SIGMA_D8B', 'SIGMA_D8B'],
#   'PhaseFraction': [0.3582448914515225, 0.6417551089856985],
#   'infeasiblePhases': 1.000000000437221},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.000000000035558],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9447490534585826, 0.05525094679864657],
#   'infeasiblePhases': 0.05525094679864657},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8021349060739618, 0.19786509385983037],
#   'infeasiblePhases': 0.19786509385983037},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.21110261731750216,
#    0.5561466691310043,
#    0.2327507269948493],
#   'infeasiblePhases': 0.2327507269948493},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.596476619150771, 0.40352338084925576],
#   'infeasiblePhases': 0},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.5067127074713714,
#    0.3876562190337574,
#    0.10563107687757511],
#   'infeasiblePhases': 0.5067127074713714},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.7587135031107571, 0.24128649673891256],
#   'infeasiblePhases': 0.7587135031107571},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000258489],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9564303334658727, 0.04356966675396195],
#   'infeasiblePhases': 0.04356966675396195},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7960298107809897, 0.2039701892248234],
#   'infeasiblePhases': 0.2039701892248234},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.33657636004653557, 0.66342363979909],
#   'infeasiblePhases': 0.33657636004653557},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.49293222818930477, 0.5070677718345276],
#   'infeasiblePhases': 0.49293222818930477},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.6959337724644215,
#    0.030906435464150478,
#    0.27315979949800206],
#   'infeasiblePhases': 0.6959337724644215},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.999999999937006],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000262288],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8008101565382285, 0.19918984415353644],
#   'infeasiblePhases': 0.19918984415353644},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.3458448251781106, 0.6541551750301433],
#   'infeasiblePhases': 0.3458448251781106},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.5236934990992419, 0.4763065008852225],
#   'infeasiblePhases': 0.5236934990992419},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000270024],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000062204],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8304188000960337, 0.1695812004805629],
#   'infeasiblePhases': 0.1695812004805629},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.669963890516379, 0.3300361095576497],
#   'infeasiblePhases': 0.3300361095576497},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000105378],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999968275],
#   'infeasiblePhases': 0},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.1043544951137188, 0.8956455043948368],
#   'infeasiblePhases': 0.1043544951137188},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000031235],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999977356],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999909301],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.7909534992983992, 0.20904650062285626],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999983041],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999888813],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000040823],
#   'infeasiblePhases': 0},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.5174421283357993, 0.4825578715118071],
#   'infeasiblePhases': 0.5174421283357993},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.35558226494082745, 0.6444177348977088],
#   'infeasiblePhases': 0.6444177348977088},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.6361790953237927, 0.36382090447564264],
#   'infeasiblePhases': 0.6361790953237927},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.41422173271069296, 0.5857782667565332],
#   'infeasiblePhases': 0.5857782667565332},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.999999999998656],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000006453],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000565832],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.8058723226102368, 0.19412767739125075],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.00000000000015],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000005653],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.999999999916019],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000038678],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9183056923025865, 0.0816943078198374],
#   'infeasiblePhases': 0.0816943078198374},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999989654],
#   'infeasiblePhases': 0},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.3058882325166376, 0.694111767390919],
#   'infeasiblePhases': 0.3058882325166376},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000190248],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.6439874917551461, 0.3560125082472809],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.732461385257026, 0.2675386147411233],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.08417747246881671, 0.9158225275371085],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000012212],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9092222797705168, 0.09077772022392495],
#   'infeasiblePhases': 0.09077772022392495},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7749620333149926, 0.22503796643035276],
#   'infeasiblePhases': 0.22503796643035276},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.39821375297405215, 0.601786247037511],
#   'infeasiblePhases': 0.39821375297405215},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000224114],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9122728536164844, 0.08772714626860094],
#   'infeasiblePhases': 0.08772714626860094},
#  {'Phases': ['L12_FCC', 'BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.5674149948718327,
#    0.2603871910182207,
#    0.17219781417774224],
#   'infeasiblePhases': 0.17219781417774224},
#  {'Phases': ['L12_FCC', 'BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.32982948246452776,
#    0.5507679107103481,
#    0.11940261305659615],
#   'infeasiblePhases': 0.11940261305659615},
#  {'Phases': ['L12_FCC', 'BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.12893965411225006,
#    0.6634395459767991,
#    0.2076208041646847],
#   'infeasiblePhases': 0.2076208041646847},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.6349580309298961, 0.3650419695658515],
#   'infeasiblePhases': 0.3650419695658515},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.4626567581062085, 0.5373432422618837],
#   'infeasiblePhases': 0.5373432422618837},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000042226],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9182831612512422, 0.08171683867012171],
#   'infeasiblePhases': 0.08171683867012171},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7653868800336855, 0.23461311994576076],
#   'infeasiblePhases': 0.23461311994576076},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.12438985406255791,
#    0.5632000222697574,
#    0.3124101237529197],
#   'infeasiblePhases': 0.3124101237529197},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.3916507438645211,
#    0.2859004232198698,
#    0.32244884223082815],
#   'infeasiblePhases': 0.3916507438645211},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.5799298000205056,
#    0.3221198426286621,
#    0.09795036302836985],
#   'infeasiblePhases': 0.5799298000205056},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000202502],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9330904426940992, 0.06690955778284281],
#   'infeasiblePhases': 0.06690955778284281},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7617515005557274, 0.2382484996919472],
#   'infeasiblePhases': 0.2382484996919472},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.6230220816983526, 0.376977918210713],
#   'infeasiblePhases': 0.376977918210713},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.5376117257456868, 0.46238827433952984],
#   'infeasiblePhases': 0.5376117257456868},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000178026],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9695660519683825, 0.030433947988544797],
#   'infeasiblePhases': 0.030433947988544797},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.2295255241392743, 0.7704744758737508],
#   'infeasiblePhases': 0.2295255241392743},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.38283030906822085, 0.6171696906174509],
#   'infeasiblePhases': 0.38283030906822085},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000385394],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999955133],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8073679599104484, 0.19263204092146077],
#   'infeasiblePhases': 0.19263204092146077},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000485259],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000073908],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000075873],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.3752035172182896, 0.6247964827569726],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999969397],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.999999999999256],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000232059],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999960449],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.5718759618259538, 0.42812403762125384],
#   'infeasiblePhases': 0.42812403762125384},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.5810235306913297, 0.4189764695656519],
#   'infeasiblePhases': 0.4189764695656519},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.6465674488142964, 0.35343255123549944],
#   'infeasiblePhases': 0.35343255123549944},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999984105],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000064526],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.23774401840084183, 0.762255981627168],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000002658],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999992507],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000666889],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999864422],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000218245],
#   'infeasiblePhases': 0},
#  {'Phases': [], 'PhaseFraction': [], 'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999558743],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7257695615740557,
#    0.20233112634349681,
#    0.07189931212064771],
#   'infeasiblePhases': 0.07189931212064771},
#  {'Phases': ['L12_FCC', 'BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.2565948850524904,
#    0.6224320055008634,
#    0.12097310940674642],
#   'infeasiblePhases': 0.12097310940674642},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.10362671741163858, 0.896373282575193],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9346733522498238, 0.06532664770930371],
#   'infeasiblePhases': 0.06532664770930371},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8435581106599006, 0.15644188967259354],
#   'infeasiblePhases': 0.15644188967259354},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.28599898523473016, 0.714001014724143],
#   'infeasiblePhases': 0.28599898523473016},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999883452],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8861369754764481, 0.11386302456431431],
#   'infeasiblePhases': 0.11386302456431431},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.16833224573418817,
#    0.6019930066613175,
#    0.22967474769753876],
#   'infeasiblePhases': 0.22967474769753876},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.4729157809722577,
#    0.32761820799462443,
#    0.19946601924548962],
#   'infeasiblePhases': 0.19946601924548962},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.21883845475588676, 0.7811615452548737],
#   'infeasiblePhases': 0},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2'],
#   'PhaseFraction': [0.4337549003295303, 0.5662450993120022],
#   'infeasiblePhases': 0.4337549003295303},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999974777],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8934888087200584, 0.10651119150111606],
#   'infeasiblePhases': 0.10651119150111606},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7304413369822076, 0.2695586630435333],
#   'infeasiblePhases': 0.2695586630435333},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.036312667590708086,
#    0.5747812305452056,
#    0.3889061020133621],
#   'infeasiblePhases': 0.3889061020133621},
#  {'Phases': ['SIGMA_D8B', 'BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.46475367028957865,
#    0.21465068775659302,
#    0.32059564186175704],
#   'infeasiblePhases': 0.46475367028957865},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999759877],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9115804498675284, 0.08841955030907271],
#   'infeasiblePhases': 0.08841955030907271},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7288929341930832, 0.27110706559562586],
#   'infeasiblePhases': 0.27110706559562586},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.415768720854884, 0.5842312791406897],
#   'infeasiblePhases': 0.415768720854884},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000143356],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.955315418593065, 0.0446845814439867],
#   'infeasiblePhases': 0.0446845814439867},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.2581502895515739, 0.7418497096602438],
#   'infeasiblePhases': 0.2581502895515739},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000485711],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000025389],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999805949],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999962813],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999959617],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999999192],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000058356],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.999999999999797],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.789804404895903, 0.21019559557054013],
#   'infeasiblePhases': 0.21019559557054013},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8009953097677212, 0.19900469084469374],
#   'infeasiblePhases': 0.19900469084469374},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8808908756727587, 0.11910912405322024],
#   'infeasiblePhases': 0.11910912405322024},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999798372],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.2848044052700908, 0.715195594754453],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000002247271],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999993636],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999988402],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000032718],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999981738],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999928212],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8033137001465711,
#    0.07267542346069568,
#    0.12401087646141028],
#   'infeasiblePhases': 0.12401087646141028},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.552612936204532,
#    0.26774146043740704,
#    0.17964560336536506],
#   'infeasiblePhases': 0.17964560336536506},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.12550458227540787, 0.874495417755449],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.869162152900084, 0.13083784729677977],
#   'infeasiblePhases': 0.13083784729677977},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.780619685057768, 0.2193803149676323],
#   'infeasiblePhases': 0.2193803149676323},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999735437],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8618723927418207, 0.13812760716965866],
#   'infeasiblePhases': 0.13812760716965866},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.06477278200371205,
#    0.6494337063997984,
#    0.28579351165400013],
#   'infeasiblePhases': 0.28579351165400013},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.392927700262902, 0.3260244310871851, 0.2810478789530711],
#   'infeasiblePhases': 0.2810478789530711},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.2357615944202333, 0.7642384055742253],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999870417],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8702019622710416, 0.12979803775096874],
#   'infeasiblePhases': 0.12979803775096874},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.6969799670012281, 0.3030200332150619],
#   'infeasiblePhases': 0.3030200332150619},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.5588644493207346, 0.44113555077200056],
#   'infeasiblePhases': 0.44113555077200056},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000168459],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8919683296020381, 0.10803167132926925],
#   'infeasiblePhases': 0.10803167132926925},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.30271325175019276, 0.697286748229646],
#   'infeasiblePhases': 0.30271325175019276},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000400553],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.9507047410033203,
#    0.048176656411441095,
#    0.0011186026378446083],
#   'infeasiblePhases': 0.0011186026378446083},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000491116],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000391152],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000001755112],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'BCC_B2'],
#   'PhaseFraction': [0.9383929068298856, 0.06160709317822643],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999986644],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999979181],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000087994],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999926189],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999978567],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.3375686184513091, 0.6624313815429649],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.887816385987915, 0.11218361396510493],
#   'infeasiblePhases': 0.11218361396510493},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999995801],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000362552],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999911426],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999718903],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8372016403702214, 0.162798359719491],
#   'infeasiblePhases': 0.162798359719491},
#  {'Phases': ['L12_FCC', 'BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.2882984084708042,
#    0.48094066027994237,
#    0.23076093125308772],
#   'infeasiblePhases': 0.23076093125308772},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.8512219735454007, 0.14877802642986893],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8057480442595006, 0.19425195563889797],
#   'infeasiblePhases': 0.19425195563889797},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.000000000001454],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8391668909532661, 0.1608331089518454],
#   'infeasiblePhases': 0.1608331089518454},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.6680967317691936, 0.33190326834010897],
#   'infeasiblePhases': 0.33190326834010897},
#  {'Phases': ['L12_FCC', 'BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.32204717083845014,
#    0.30649163900027987,
#    0.3714612017854826],
#   'infeasiblePhases': 0.3714612017854826},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000081979],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.848311762129428, 0.15168823824255154],
#   'infeasiblePhases': 0.15168823824255154},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.3352760758196611, 0.6647239242493759],
#   'infeasiblePhases': 0.3352760758196611},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999907312],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8743947047150605, 0.12560529585650676],
#   'infeasiblePhases': 0.12560529585650676},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.002437425138614549, 0.9975625749014336],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.999999999976999],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999998909881],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'BCC_B2'],
#   'PhaseFraction': [0.1561141413035978, 0.843885858692963],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000005604],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999994018],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.000000000006169],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999897297],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2', 'BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.4279285319875362,
#    0.05947823031761675,
#    0.48832592123172514,
#    0.02426731636699239],
#   'infeasiblePhases': 0.02426731636699239},
#  {'Phases': [], 'PhaseFraction': [], 'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999995647],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999412503],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999924195],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8168280801708069, 0.1831719198903726],
#   'infeasiblePhases': 0.1831719198903726},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.5479336087323663, 0.452066391256398],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.665922038397503, 0.06147049687883974, 0.272607469507603],
#   'infeasiblePhases': 0.272607469507603},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000168594],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8177571852555203, 0.18224281438870601],
#   'infeasiblePhases': 0.18224281438870601},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.6367481741270106, 0.3632518257484933],
#   'infeasiblePhases': 0.3632518257484933},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999864588],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.8277741558222339, 0.17222584377359879],
#   'infeasiblePhases': 0.17222584377359879},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000097269],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000095868],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000000713],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000054936],
#   'infeasiblePhases': 0},
#  {'Phases': [], 'PhaseFraction': [], 'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000013052],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999935965],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.21488521707025224,
#    0.5811366082089632,
#    0.2039781747283814],
#   'infeasiblePhases': 0},
#  {'Phases': [], 'PhaseFraction': [], 'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [0.9999999999999],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999846252],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.022563642423928307,
#    0.7940668776399148,
#    0.18336947829510977],
#   'infeasiblePhases': 0.18336947829510977},
#  {'Phases': ['L12_FCC', 'BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.3609429726048839,
#    0.31470570945752857,
#    0.32435131800158284],
#   'infeasiblePhases': 0.32435131800158284},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999955872],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7974390597403983, 0.202560940003869],
#   'infeasiblePhases': 0.202560940003869},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000016005],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000112081],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.0000000000003915],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'BCC_B2'],
#   'PhaseFraction': [0.701251419032586, 0.29874858096847756],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2'],
#   'PhaseFraction': [1.000000000001139],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000254532],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC', 'BCC_B2'],
#   'PhaseFraction': [0.7109972821546574, 0.2890027178183921],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'SIGMA_D8B'],
#   'PhaseFraction': [0.7522452805302613, 0.24775471897587842],
#   'infeasiblePhases': 0.24775471897587842},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999997101],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC', 'SIGMA_D8B'],
#   'PhaseFraction': [0.057667368345722156,
#    0.7707377710818744,
#    0.17159485961985532],
#   'infeasiblePhases': 0.17159485961985532},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000150902],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [1.0000000000016667],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.9220237781147526,
#    0.04379288812694851,
#    0.034183333767324096],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'BCC_B2'],
#   'PhaseFraction': [0.6418444688948022, 0.3581555311143097],
#   'infeasiblePhases': 0},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999939138],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.2974720153962891, 0.7025279846189946],
#   'infeasiblePhases': 0},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.00170173049545367, 0.9982982693236298],
#   'infeasiblePhases': 0.00170173049545367},
#  {'Phases': ['L12_FCC'],
#   'PhaseFraction': [0.9999999999629381],
#   'infeasiblePhases': 0},
#  {'Phases': ['BCC_B2', 'BCC_B2', 'L12_FCC'],
#   'PhaseFraction': [0.7202536260485312,
#    0.12528520760869089,
#    0.1544611663723293],
#   'infeasiblePhases': 0},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.012002421326355825, 0.9879975779635775],
#   'infeasiblePhases': 0.012002421326355825},
#  {'Phases': ['SIGMA_D8B', 'L12_FCC'],
#   'PhaseFraction': [0.029135195949625915, 0.9708648040040848],
#   'infeasiblePhases': 0.029135195949625915}]

# %%
for phase in gridPhases:
    gridPhases['infeasiblePhases'] = sum(phase['PhaseFraction'][i] for i, p in enumerate(phase['Phases']) if p in infeasiblePhases)

# %%
gridPhases[121]['infeasiblePhases']
# Out:
# 0.9999999993341405

# %%
phases1 = [gridPhases[i]['Phases'] for i in range(len(gridPhases))]
sum1= [gridPhases[i]['infeasiblePhases'] for i in range(len(gridPhases))]

# %% [markdown]
# Now, let's turn that list of phases into a list of feasibility based on the constraint we defined earlier. Note that in some cases, the `pycalphad` library may return an empty list of phases, which we will treat as infeasible.

# %%
infeasiblePhases = set([
    'AL3M', 'AL5FE2', 'LIQUID', 'AL11CR4', 'D82_217', 'AL3NI1', 'NI3TI', 'AL5FE4', 'TAOA', 'LAVES_C15', 'GAMMAH', 'AL5CR', 'AL2FE', 'AL4CR', 'NIV3_A15', 'GAMMA_H', 
    'ALTI3_D019', 'ALCU_DELTA', 'AL45CR7', 'TS01TI', 'NI8V', 'AL45CR7_12', 'LAVES_C14', 'LAVES_A15', 'AL3NI5', 'AL5TI3', 'ALCU_EPSILON', 'NITI2', 'AL8V5', 'ALCR2', 'AL23V4', 'AL13FE4', 
    'AL4NI3', 'ALCU_ZETA', 'ALCU_THETA', 'AL3NI2', 'AL23V4_194', 'CRNI2', 'NI3V_D022', 'LAVES_C36', 'TS01T3', 'AL21V2_227', 'AL5TI2', 'ALCU_ETA', 'GAMMAL', 
    'GAMMA_D83', 'SIGMA_D8B', 'AL21V2', 'AL2TI', 'AL3TI_L', 'ALTI', 'AL45V7'])
print(f"Feasible phases set: {set(phases).difference(infeasiblePhases)}")
gridFeasible = [len(set(p) & infeasiblePhases)==0 and p!=[] for p in phases1]
gridFeasible[120:130]
# Out:
# Feasible phases set: {'HCP_A3', 'FCC_A1', 'BCC_B2', 'L12_FCC', 'BCC_A2'}
# [False, False, False, False, True, True, True, True, False, False]

# %% [markdown]
# Finally, let's plot the result in 3D using the `plotly` library and our spacial-transformed attainable space grid we obtained with `plotting.simplex2cartesian_py(gridAtt)` earlier.
#
# **Once you run the cell below, you should be seeing an interactive 3D plot with 455 split roughly 50/50 between feasible and infeasible points. You can rotate the plot, zoom in and out, and hover over the points to see their composition and feasibility. You can also click on the legend to hide/show the points based on their feasibility.**

# %%
fig = px.scatter_3d(gridAtt_projected_df, x='x', y='y', z='z', color=gridFeasible, text=labels, hover_name=formulas,
              template='plotly_white', width=800, height=700, opacity=0.333, color_discrete_sequence=['green', 'red'],
              labels={'color':'Solid Solution Phases', 'x':'', 'y':'', 'z':''})
fig.update_scenes({'camera': {'eye': {'x': -2.3, 'y': 0.2, 'z': 0.2}}})
# Out:
# <div>                            <div id="b87d465f-cd84-40df-bd25-35ac422fa2c1" class="plotly-graph-div" style="height:700px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b87d465f-cd84-40df-bd25-35ac422fa2c1")) {                    Plotly.newPlot(                        "b87d465f-cd84-40df-bd25-35ac422fa2c1",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSolid Solution Phases=True\u003cbr\u003e=%{z}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["(  0) Fe100.0 ","(  1) V8.3 Fe91.7 ","(  2) V16.7 Fe83.3 ","(  9) V75.0 Fe25.0 ","( 10) V83.3 Fe16.7 ","( 11) V91.7 Fe8.3 ","( 12) V100.0 ","( 13) Ni6.7 Cr1.7 Fe91.7 ","( 14) V8.3 Ni6.7 Cr1.7 Fe83.3 ","( 15) V16.7 Ni6.7 Cr1.7 Fe75.0 ","( 16) V25.0 Ni6.7 Cr1.7 Fe66.7 ","( 25) Ni13.3 Cr3.3 Fe83.3 ","( 26) V8.3 Ni13.3 Cr3.3 Fe75.0 ","( 27) V16.7 Ni13.3 Cr3.3 Fe66.7 ","( 28) V25.0 Ni13.3 Cr3.3 Fe58.3 ","( 29) V33.3 Ni13.3 Cr3.3 Fe50.0 ","( 30) V41.7 Ni13.3 Cr3.3 Fe41.7 ","( 36) Ni20.0 Cr5.0 Fe75.0 ","( 37) V8.3 Ni20.0 Cr5.0 Fe66.7 ","( 38) V16.7 Ni20.0 Cr5.0 Fe58.3 ","( 39) V25.0 Ni20.0 Cr5.0 Fe50.0 ","( 40) V33.3 Ni20.0 Cr5.0 Fe41.7 ","( 46) Ni26.7 Cr6.7 Fe66.7 ","( 47) V8.3 Ni26.7 Cr6.7 Fe58.3 ","( 49) V25.0 Ni26.7 Cr6.7 Fe41.7 ","( 55) Ni33.3 Cr8.3 Fe58.3 ","( 56) V8.3 Ni33.3 Cr8.3 Fe50.0 ","( 63) Ni40.0 Cr10.0 Fe50.0 ","( 64) V8.3 Ni40.0 Cr10.0 Fe41.7 ","( 70) Ni46.7 Cr11.7 Fe41.7 ","( 71) V8.3 Ni46.7 Cr11.7 Fe33.3 ","( 76) Ni53.3 Cr13.3 Fe33.3 ","( 77) V8.3 Ni53.3 Cr13.3 Fe25.0 ","( 81) Ni60.0 Cr15.0 Fe25.0 ","( 82) V8.3 Ni60.0 Cr15.0 Fe16.7 ","( 83) V16.7 Ni60.0 Cr15.0 Fe8.3 ","( 85) Ni66.7 Cr16.7 Fe16.7 ","( 86) V8.3 Ni66.7 Cr16.7 Fe8.3 ","( 87) V16.7 Ni66.7 Cr16.7 ","( 88) Ni73.3 Cr18.3 Fe8.3 ","( 89) V8.3 Ni73.3 Cr18.3 ","( 90) Ni80.0 Cr20.0 ","( 91) Ni0.8 Cr1.7 Fe97.5 ","( 92) V8.3 Ni0.8 Cr1.7 Fe89.2 ","( 93) V16.7 Ni0.8 Cr1.7 Fe80.9 ","(100) V75.0 Ni0.8 Cr1.7 Fe22.5 ","(101) V83.3 Ni0.8 Cr1.7 Fe14.2 ","(102) V91.7 Ni0.8 Cr1.7 Fe5.9 ","(103) Ni7.5 Cr3.3 Fe89.2 ","(104) V8.3 Ni7.5 Cr3.3 Fe80.9 ","(105) V16.7 Ni7.5 Cr3.3 Fe72.5 ","(106) V25.0 Ni7.5 Cr3.3 Fe64.2 ","(107) V33.3 Ni7.5 Cr3.3 Fe55.9 ","(114) Ni14.1 Cr5.0 Fe80.9 ","(115) V8.3 Ni14.1 Cr5.0 Fe72.5 ","(116) V16.7 Ni14.1 Cr5.0 Fe64.2 ","(117) V25.0 Ni14.1 Cr5.0 Fe55.9 ","(118) V33.3 Ni14.1 Cr5.0 Fe47.5 ","(119) V41.7 Ni14.1 Cr5.0 Fe39.2 ","(124) Ni20.8 Cr6.7 Fe72.5 ","(125) V8.3 Ni20.8 Cr6.7 Fe64.2 ","(126) V16.7 Ni20.8 Cr6.7 Fe55.9 ","(127) V25.0 Ni20.8 Cr6.7 Fe47.5 ","(133) Ni27.5 Cr8.3 Fe64.2 ","(141) Ni34.1 Cr10.0 Fe55.9 ","(148) Ni40.8 Cr11.7 Fe47.5 ","(149) V8.3 Ni40.8 Cr11.7 Fe39.2 ","(154) Ni47.5 Cr13.3 Fe39.2 ","(155) V8.3 Ni47.5 Cr13.3 Fe30.9 ","(159) Ni54.1 Cr15.0 Fe30.9 ","(160) V8.3 Ni54.1 Cr15.0 Fe22.5 ","(163) Ni60.8 Cr16.7 Fe22.5 ","(164) V8.3 Ni60.8 Cr16.7 Fe14.2 ","(165) V16.7 Ni60.8 Cr16.7 Fe5.9 ","(166) Ni67.5 Cr18.3 Fe14.2 ","(167) V8.3 Ni67.5 Cr18.3 Fe5.9 ","(168) Ni74.1 Cr20.0 Fe5.9 ","(169) Ni1.6 Cr3.3 Fe95.1 ","(170) V8.3 Ni1.6 Cr3.3 Fe86.7 ","(171) V16.7 Ni1.6 Cr3.3 Fe78.4 ","(178) V75.0 Ni1.6 Cr3.3 Fe20.1 ","(179) V83.3 Ni1.6 Cr3.3 Fe11.7 ","(180) Ni8.3 Cr5.0 Fe86.7 ","(181) V8.3 Ni8.3 Cr5.0 Fe78.4 ","(182) V16.7 Ni8.3 Cr5.0 Fe70.1 ","(183) V25.0 Ni8.3 Cr5.0 Fe61.7 ","(184) V33.3 Ni8.3 Cr5.0 Fe53.4 ","(190) Ni14.9 Cr6.7 Fe78.4 ","(191) V8.3 Ni14.9 Cr6.7 Fe70.1 ","(192) V16.7 Ni14.9 Cr6.7 Fe61.7 ","(193) V25.0 Ni14.9 Cr6.7 Fe53.4 ","(194) V33.3 Ni14.9 Cr6.7 Fe45.1 ","(196) V50.0 Ni14.9 Cr6.7 Fe28.4 ","(199) Ni21.6 Cr8.3 Fe70.1 ","(202) V25.0 Ni21.6 Cr8.3 Fe45.1 ","(207) Ni28.3 Cr10.0 Fe61.7 ","(211) V33.3 Ni28.3 Cr10.0 Fe28.4 ","(214) Ni34.9 Cr11.7 Fe53.4 ","(220) Ni41.6 Cr13.3 Fe45.1 ","(221) V8.3 Ni41.6 Cr13.3 Fe36.7 ","(225) Ni48.3 Cr15.0 Fe36.7 ","(226) V8.3 Ni48.3 Cr15.0 Fe28.4 ","(229) Ni54.9 Cr16.7  ...

# %%
# Create a color gradient based on the values of gridInfeasible
color_scale = [[0, 'green'], [1, 'red']]

# Create a DataFrame with the values of gridInfeasible
df = pd.DataFrame({'gridInfeasible': sum1})
df['index'] = gridAtt_projected_df.index
# Now, merge the DataFrames on this index
merged_df = pd.merge(gridAtt_projected_df, df, left_index=True, right_on='index')

# Plot the values using px.scatter_3d
fig = px.scatter_3d(merged_df, x='x', y='y', z='z', color='gridInfeasible', text=labels, hover_name=formulas,template='plotly_white', width=800, height=700, opacity=0.666,
                    color_continuous_scale=color_scale)

# Update the layout of the figure
fig.update_layout(scene=dict(xaxis_title='Index', yaxis_title='gridInfeasible', zaxis_title=''),
                  title='gridInfeasible Color Gradient')

fig.update_scenes({'camera': {'eye': {'x': -2.3, 'y': 0.2, 'z': 0.2}}})

# Show the figure
fig.show()
# Out:
# <div>                            <div id="695a78f5-eca5-4b3d-bfe0-1b4cfb00a3e2" class="plotly-graph-div" style="height:700px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("695a78f5-eca5-4b3d-bfe0-1b4cfb00a3e2")) {                    Plotly.newPlot(                        "695a78f5-eca5-4b3d-bfe0-1b4cfb00a3e2",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cbr\u003etext=%{text}\u003cbr\u003egridInfeasible=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["(  0) Fe100.0 ","(  1) V8.3 Fe91.7 ","(  2) V16.7 Fe83.3 ","(  3) V25.0 Fe75.0 ","(  4) V33.3 Fe66.7 ","(  5) V41.7 Fe58.3 ","(  6) V50.0 Fe50.0 ","(  7) V58.3 Fe41.7 ","(  8) V66.7 Fe33.3 ","(  9) V75.0 Fe25.0 ","( 10) V83.3 Fe16.7 ","( 11) V91.7 Fe8.3 ","( 12) V100.0 ","( 13) Ni6.7 Cr1.7 Fe91.7 ","( 14) V8.3 Ni6.7 Cr1.7 Fe83.3 ","( 15) V16.7 Ni6.7 Cr1.7 Fe75.0 ","( 16) V25.0 Ni6.7 Cr1.7 Fe66.7 ","( 17) V33.3 Ni6.7 Cr1.7 Fe58.3 ","( 18) V41.7 Ni6.7 Cr1.7 Fe50.0 ","( 19) V50.0 Ni6.7 Cr1.7 Fe41.7 ","( 20) V58.3 Ni6.7 Cr1.7 Fe33.3 ","( 21) V66.7 Ni6.7 Cr1.7 Fe25.0 ","( 22) V75.0 Ni6.7 Cr1.7 Fe16.7 ","( 23) V83.3 Ni6.7 Cr1.7 Fe8.3 ","( 24) V91.7 Ni6.7 Cr1.7 ","( 25) Ni13.3 Cr3.3 Fe83.3 ","( 26) V8.3 Ni13.3 Cr3.3 Fe75.0 ","( 27) V16.7 Ni13.3 Cr3.3 Fe66.7 ","( 28) V25.0 Ni13.3 Cr3.3 Fe58.3 ","( 29) V33.3 Ni13.3 Cr3.3 Fe50.0 ","( 30) V41.7 Ni13.3 Cr3.3 Fe41.7 ","( 31) V50.0 Ni13.3 Cr3.3 Fe33.3 ","( 32) V58.3 Ni13.3 Cr3.3 Fe25.0 ","( 33) V66.7 Ni13.3 Cr3.3 Fe16.7 ","( 34) V75.0 Ni13.3 Cr3.3 Fe8.3 ","( 35) V83.3 Ni13.3 Cr3.3 ","( 36) Ni20.0 Cr5.0 Fe75.0 ","( 37) V8.3 Ni20.0 Cr5.0 Fe66.7 ","( 38) V16.7 Ni20.0 Cr5.0 Fe58.3 ","( 39) V25.0 Ni20.0 Cr5.0 Fe50.0 ","( 40) V33.3 Ni20.0 Cr5.0 Fe41.7 ","( 41) V41.7 Ni20.0 Cr5.0 Fe33.3 ","( 42) V50.0 Ni20.0 Cr5.0 Fe25.0 ","( 43) V58.3 Ni20.0 Cr5.0 Fe16.7 ","( 44) V66.7 Ni20.0 Cr5.0 Fe8.3 ","( 45) V75.0 Ni20.0 Cr5.0 ","( 46) Ni26.7 Cr6.7 Fe66.7 ","( 47) V8.3 Ni26.7 Cr6.7 Fe58.3 ","( 48) V16.7 Ni26.7 Cr6.7 Fe50.0 ","( 49) V25.0 Ni26.7 Cr6.7 Fe41.7 ","( 50) V33.3 Ni26.7 Cr6.7 Fe33.3 ","( 51) V41.7 Ni26.7 Cr6.7 Fe25.0 ","( 52) V50.0 Ni26.7 Cr6.7 Fe16.7 ","( 53) V58.3 Ni26.7 Cr6.7 Fe8.3 ","( 54) V66.7 Ni26.7 Cr6.7 ","( 55) Ni33.3 Cr8.3 Fe58.3 ","( 56) V8.3 Ni33.3 Cr8.3 Fe50.0 ","( 57) V16.7 Ni33.3 Cr8.3 Fe41.7 ","( 58) V25.0 Ni33.3 Cr8.3 Fe33.3 ","( 59) V33.3 Ni33.3 Cr8.3 Fe25.0 ","( 60) V41.7 Ni33.3 Cr8.3 Fe16.7 ","( 61) V50.0 Ni33.3 Cr8.3 Fe8.3 ","( 62) V58.3 Ni33.3 Cr8.3 ","( 63) Ni40.0 Cr10.0 Fe50.0 ","( 64) V8.3 Ni40.0 Cr10.0 Fe41.7 ","( 65) V16.7 Ni40.0 Cr10.0 Fe33.3 ","( 66) V25.0 Ni40.0 Cr10.0 Fe25.0 ","( 67) V33.3 Ni40.0 Cr10.0 Fe16.7 ","( 68) V41.7 Ni40.0 Cr10.0 Fe8.3 ","( 69) V50.0 Ni40.0 Cr10.0 ","( 70) Ni46.7 Cr11.7 Fe41.7 ","( 71) V8.3 Ni46.7 Cr11.7 Fe33.3 ","( 72) V16.7 Ni46.7 Cr11.7 Fe25.0 ","( 73) V25.0 Ni46.7 Cr11.7 Fe16.7 ","( 74) V33.3 Ni46.7 Cr11.7 Fe8.3 ","( 75) V41.7 Ni46.7 Cr11.7 ","( 76) Ni53.3 Cr13.3 Fe33.3 ","( 77) V8.3 Ni53.3 Cr13.3 Fe25.0 ","( 78) V16.7 Ni53.3 Cr13.3 Fe16.7 ","( 79) V25.0 Ni53.3 Cr13.3 Fe8.3 ","( 80) V33.3 Ni53.3 Cr13.3 ","( 81) Ni60.0 Cr15.0 Fe25.0 ","( 82) V8.3 Ni60.0 Cr15.0 Fe16.7 ","( 83) V16.7 Ni60.0 Cr15.0 Fe8.3 ","( 84) V25.0 Ni60.0 Cr15.0 ","( 85) Ni66.7 Cr16.7 Fe16.7 ","( 86) V8.3 Ni66.7 Cr16.7 Fe8.3 ","( 87) V16.7 Ni66.7 Cr16.7 ","( 88) Ni73.3 Cr18.3 Fe8.3 ","( 89) V8.3 Ni73.3 Cr18.3 ","( 90) Ni80.0 Cr20.0 ","( 91) Ni0.8 Cr1.7 Fe97.5 ","( 92) V8.3 Ni0.8 Cr1.7 Fe89.2 ","( 93) V16.7 Ni0.8 Cr1.7 Fe80.9 ","( 94) V25.0 Ni0.8 Cr1.7 Fe72.5 ","( 95) V33.3 Ni0.8 Cr1.7 Fe64.2 ","( 96) V41.7 Ni0.8 Cr1.7 Fe55.9 ","( 97) V50.0 Ni0.8 Cr1.7 Fe47.5 ","( 98) V58.3 Ni0.8 Cr1.7 Fe39.2 ","( 99) V66.7 Ni0.8 Cr1.7 Fe30.9 ","(100) V75.0 Ni0.8 Cr1.7 Fe22.5 ","(101) V83.3 Ni0.8 Cr1.7 Fe14.2 " ...

# %% [markdown]
# ## Graph Walk aka Infeasibility Gliding (Exciting Stuff!)
#
# **While the last two sections highlighted the elegant abstraction of grid generation and space transformation using `nimplex`, they did not really show the true power of the library or the novel combinatorics-based algorithm we developed in the associated paper. That is the simplex graph construction in arbitrary dimensions and the graph traversal it enables.**
#
# **Let's start by generating the graph for our problem. We can use the `nimplex.embeddedpair_simplex_graph_fractional_py` function, which also first generates the two grids we already used in the previous sections.**

# %%
_, _, graphN = nimplex.embeddedpair_simplex_graph_fractional_py(attainableSpaceComponentPositions, 12)

# %% [markdown]
# As you can see, we immediately obtain list of adjecent nodes (compostions) for each node in the graph, with few neighbors for the corners and many for the interior points. This is the power of the abstraction we are talking about!

# %%
graphN[:5]
# Out:
# [[1, 13, 91],
#  [0, 2, 13, 14, 91, 92],
#  [1, 3, 14, 15, 92, 93],
#  [2, 4, 15, 16, 93, 94],
#  [3, 5, 16, 17, 94, 95]]

# %%
graphN[200:205]
# Out:
# [[134, 126, 125, 192, 191, 199, 201, 207, 208, 255, 262, 263],
#  [135, 127, 126, 193, 192, 200, 202, 208, 209, 256, 263, 264],
#  [136, 128, 127, 194, 193, 201, 203, 209, 210, 257, 264, 265],
#  [137, 129, 128, 195, 194, 202, 204, 210, 211, 258, 265, 266],
#  [138, 130, 129, 196, 195, 203, 205, 211, 212, 259, 266, 267]]

# %% [markdown]
# We can now use this graph to do a lot of things. Let's start by considering that **the infeasible region, for thermodynamic reasons beyond the scope of this tutorial, are generally difficult to predict but are generally bound by continous surfaces called phase boundaries.**
#
# **Thus, if we iteratively traverse the graph expanding only the feasible nodes, while noting infeasible nodes, we can glide along the phase boundaries and explore the feasible space without ever wasting our resources on calculations inside the insides of the infeasible regions.**
#
# Let's do this starting from the `W10.0 Nb10.0 Mo80.0` and terminating when we reach the `Hf95.0 Zr5.0` point.
#
# **Bonus Exercises:**
# - Please note that you do not need to specify the termination point, as the algorithm will stop when it completeley explores the feasible space. In this example, we are just showing you how to specify it and it has no effect on the result. If you want to play a bit, you can set `endNode` to `12` to see how path to `W33.3 Nb33.3 Ta33.3` gets explored in just 87 nodes.
# - If you remove the `endNode` termination (change `break` to `pass`), you can add the endNode (or any other node you believe is feasible) to the initial `queue` list and see how the algorithm explores the feasible space from multiple starting points much faster thanks to better parallelization.

# %%
startingNode = 0
endNode = 90

print(f"Starting node: {formulas[startingNode]}")
print(f"Ending node: {formulas[endNode]}")
# Out:
# Starting node: (  0) Fe100.0
# Ending node: ( 90) Ni80.0 Cr20.0

# %%
gridFeasible = [None]*len(graphN)
queue = [0, 12, 90]
explored = set()
calcCount = 0

# %% [markdown]
# **Now, we will be using a `queue` of nodes to keep track of the nodes we need to visit and a set of visited nodes to avoid revisiting them. This simple procedure is a type of `depth-first search` algorithm that is guaranteed to find the shortest path between two points in a graph if it exists, while exploring the feasible space in the process in an unbiased way. In a more elaborate problem, you would likely want to implement a priority queue to explore the space in a more efficient way, but for this tutorial, this is more than enough and allows for better, more direct comparions with the typical complete exploration approach.** On the 4-core Codespaces VM you can expect it to take around 1-2 minutes. In a relatively simple problem like this one, the difference between the two approaches is not that big, coming partially from overhead of limited Python parallelization capabilities, but in a more complex problem, the difference can be dramatic.

# %%
while len(queue)>0:
    print(f"Queue: {queue}")
    # Assign feasibilities to the current queue
    elPositions = [gridEl[i] for i in queue]
    if len(queue)>3:
        phases = process_map(equilibrium_callable, elPositions, max_workers=4)
    else:
        phases = [equilibrium_callable(elP) for elP in elPositions]
    feasibilities = [len(set(p) & set(infeasiblePhases))==0 and p!=[] for p in phases]

    calcCount += len(feasibilities)
    explored = explored.union(queue)

    # Create next queue based on neighbors of feasible points
    nextQueue = set()
    for f, i in zip(feasibilities, queue):
        gridFeasible[i] = f
        # Only if feasible
        if f:
            for n in graphN[i]:
                if n not in explored:
                    nextQueue.add(n)

    # Early termination criteria if we just evaluated the target
    if endNode in queue:
        pass

    print(f"Calculations done: {calcCount}")
    queue = list(nextQueue)
# Out:
# Queue: [0, 12, 90]
# Calculations done: 3
# Queue: [1, 102, 88, 168, 11, 13, 24, 89, 91]
#   0%|          | 0/9 [00:00<?, ?it/s]
# Calculations done: 12
# Queue: [2, 101, 166, 167, 103, 169, 234, 10, 14, 113, 179, 85, 86, 23, 87, 25, 92]
#   0%|          | 0/17 [00:00<?, ?it/s]
# Calculations done: 29
# Queue: [3, 9, 15, 22, 26, 289, 163, 164, 165, 36, 170, 178, 180, 189, 81, 82, 83, 84, 93, 100, 232, 233, 104, 235, 112, 114, 244]
#   0%|          | 0/27 [00:00<?, ?it/s]
# Calculations done: 56
# Queue: [8, 16, 21, 27, 159, 288, 160, 161, 162, 287, 37, 290, 298, 171, 46, 177, 181, 188, 190, 76, 77, 334, 78, 79, 94, 99, 229, 230, 231, 105, 236, 111, 115, 243, 245, 124, 253]
#   0%|          | 0/37 [00:00<?, ?it/s]
# Calculations done: 93
# Queue: [4, 133, 17, 154, 155, 156, 284, 28, 285, 286, 291, 38, 297, 299, 172, 47, 306, 182, 55, 191, 70, 199, 71, 72, 332, 333, 335, 342, 225, 226, 227, 106, 237, 370, 242, 116, 246, 252, 125, 254]
#   0%|          | 0/40 [00:00<?, ?it/s]
# Calculations done: 133
# Queue: [260, 5, 134, 262, 261, 141, 398, 18, 148, 149, 150, 280, 281, 282, 29, 292, 39, 300, 48, 305, 307, 183, 56, 187, 63, 192, 64, 65, 197, 200, 329, 330, 331, 207, 336, 343, 220, 221, 222, 95, 107, 238, 368, 369, 371, 117, 247, 251, 126, 255]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Calculations done: 183
# Queue: [256, 263, 135, 396, 269, 142, 397, 143, 399, 275, 276, 30, 419, 293, 40, 296, 301, 173, 304, 49, 308, 312, 313, 314, 184, 57, 193, 325, 326, 201, 208, 337, 341, 214, 215, 344, 216, 348, 349, 350, 96, 108, 365, 366, 239, 372, 118, 248, 378, 127]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Calculations done: 233
# Queue: [128, 257, 384, 259, 264, 393, 394, 136, 270, 400, 19, 405, 31, 417, 418, 420, 294, 295, 41, 302, 303, 174, 434, 50, 309, 311, 185, 58, 315, 320, 321, 194, 202, 338, 340, 345, 347, 351, 354, 355, 356, 361, 377, 362, 373, 119, 376, 249, 250, 379, 382, 383]
#   0%|          | 0/52 [00:00<?, ?it/s]
# Calculations done: 285
# Queue: [385, 258, 129, 387, 389, 390, 388, 265, 401, 403, 404, 406, 408, 409, 410, 414, 415, 421, 425, 432, 433, 435, 310, 186, 444, 195, 203, 209, 210, 339, 346, 352, 353, 357, 109, 240, 241, 374, 375, 120, 380, 381]
#   0%|          | 0/42 [00:00<?, ?it/s]
# Calculations done: 327
# Queue: [386, 391, 392, 266, 402, 407, 411, 412, 413, 422, 423, 424, 426, 427, 428, 429, 430, 436, 439, 442, 443, 316, 445, 317, 450, 358, 359]
#   0%|          | 0/27 [00:00<?, ?it/s]
# Calculations done: 354
# Queue: [416, 448, 451, 431, 437, 438, 440, 441, 446]
#   0%|          | 0/9 [00:00<?, ?it/s]
# Calculations done: 363
# Queue: [449, 452, 453, 454, 447]
#   0%|          | 0/5 [00:00<?, ?it/s]
# Calculations done: 368

# %% [markdown]
# **You should now see that only 281 phase equilibria calculations were performed to get all the feasible points! That's only a bit more than half of what we had to do in the previous section. Let's plot the path we found in the 3D space.** If you rotate the figure, you can clearly see the path gliding along the infeasible space boundary.

# %%
fig = px.scatter_3d(gridAtt_projected_df, x='x', y='y', z='z', color=gridFeasible, text=labels, hover_name=formulas,
              template='plotly_white', width=800, height=700, opacity=0.333, color_discrete_sequence=['green', 'red'],
              labels={'color':'Solid Solution Phases', 'x':'', 'y':'', 'z':''})
fig.update_scenes({'camera': {'eye': {'x': -2.3, 'y': 0.2, 'z': 0.2}}})
# Out:
# <div>                            <div id="bce919de-9534-437a-a568-64783609a629" class="plotly-graph-div" style="height:700px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bce919de-9534-437a-a568-64783609a629")) {                    Plotly.newPlot(                        "bce919de-9534-437a-a568-64783609a629",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSolid Solution Phases=True\u003cbr\u003e=%{z}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["(  0) Fe100.0 ","(  1) V8.3 Fe91.7 ","(  2) V16.7 Fe83.3 ","(  9) V75.0 Fe25.0 ","( 10) V83.3 Fe16.7 ","( 11) V91.7 Fe8.3 ","( 12) V100.0 ","( 13) Ni6.7 Cr1.7 Fe91.7 ","( 14) V8.3 Ni6.7 Cr1.7 Fe83.3 ","( 15) V16.7 Ni6.7 Cr1.7 Fe75.0 ","( 16) V25.0 Ni6.7 Cr1.7 Fe66.7 ","( 17) V33.3 Ni6.7 Cr1.7 Fe58.3 ","( 25) Ni13.3 Cr3.3 Fe83.3 ","( 26) V8.3 Ni13.3 Cr3.3 Fe75.0 ","( 27) V16.7 Ni13.3 Cr3.3 Fe66.7 ","( 28) V25.0 Ni13.3 Cr3.3 Fe58.3 ","( 29) V33.3 Ni13.3 Cr3.3 Fe50.0 ","( 30) V41.7 Ni13.3 Cr3.3 Fe41.7 ","( 36) Ni20.0 Cr5.0 Fe75.0 ","( 37) V8.3 Ni20.0 Cr5.0 Fe66.7 ","( 38) V16.7 Ni20.0 Cr5.0 Fe58.3 ","( 39) V25.0 Ni20.0 Cr5.0 Fe50.0 ","( 40) V33.3 Ni20.0 Cr5.0 Fe41.7 ","( 46) Ni26.7 Cr6.7 Fe66.7 ","( 47) V8.3 Ni26.7 Cr6.7 Fe58.3 ","( 49) V25.0 Ni26.7 Cr6.7 Fe41.7 ","( 55) Ni33.3 Cr8.3 Fe58.3 ","( 56) V8.3 Ni33.3 Cr8.3 Fe50.0 ","( 63) Ni40.0 Cr10.0 Fe50.0 ","( 64) V8.3 Ni40.0 Cr10.0 Fe41.7 ","( 70) Ni46.7 Cr11.7 Fe41.7 ","( 71) V8.3 Ni46.7 Cr11.7 Fe33.3 ","( 76) Ni53.3 Cr13.3 Fe33.3 ","( 77) V8.3 Ni53.3 Cr13.3 Fe25.0 ","( 81) Ni60.0 Cr15.0 Fe25.0 ","( 82) V8.3 Ni60.0 Cr15.0 Fe16.7 ","( 83) V16.7 Ni60.0 Cr15.0 Fe8.3 ","( 85) Ni66.7 Cr16.7 Fe16.7 ","( 86) V8.3 Ni66.7 Cr16.7 Fe8.3 ","( 87) V16.7 Ni66.7 Cr16.7 ","( 88) Ni73.3 Cr18.3 Fe8.3 ","( 89) V8.3 Ni73.3 Cr18.3 ","( 90) Ni80.0 Cr20.0 ","( 91) Ni0.8 Cr1.7 Fe97.5 ","( 92) V8.3 Ni0.8 Cr1.7 Fe89.2 ","( 93) V16.7 Ni0.8 Cr1.7 Fe80.9 ","(100) V75.0 Ni0.8 Cr1.7 Fe22.5 ","(101) V83.3 Ni0.8 Cr1.7 Fe14.2 ","(102) V91.7 Ni0.8 Cr1.7 Fe5.9 ","(103) Ni7.5 Cr3.3 Fe89.2 ","(104) V8.3 Ni7.5 Cr3.3 Fe80.9 ","(105) V16.7 Ni7.5 Cr3.3 Fe72.5 ","(106) V25.0 Ni7.5 Cr3.3 Fe64.2 ","(107) V33.3 Ni7.5 Cr3.3 Fe55.9 ","(114) Ni14.1 Cr5.0 Fe80.9 ","(115) V8.3 Ni14.1 Cr5.0 Fe72.5 ","(116) V16.7 Ni14.1 Cr5.0 Fe64.2 ","(117) V25.0 Ni14.1 Cr5.0 Fe55.9 ","(118) V33.3 Ni14.1 Cr5.0 Fe47.5 ","(119) V41.7 Ni14.1 Cr5.0 Fe39.2 ","(124) Ni20.8 Cr6.7 Fe72.5 ","(125) V8.3 Ni20.8 Cr6.7 Fe64.2 ","(126) V16.7 Ni20.8 Cr6.7 Fe55.9 ","(127) V25.0 Ni20.8 Cr6.7 Fe47.5 ","(133) Ni27.5 Cr8.3 Fe64.2 ","(141) Ni34.1 Cr10.0 Fe55.9 ","(148) Ni40.8 Cr11.7 Fe47.5 ","(149) V8.3 Ni40.8 Cr11.7 Fe39.2 ","(154) Ni47.5 Cr13.3 Fe39.2 ","(155) V8.3 Ni47.5 Cr13.3 Fe30.9 ","(159) Ni54.1 Cr15.0 Fe30.9 ","(160) V8.3 Ni54.1 Cr15.0 Fe22.5 ","(163) Ni60.8 Cr16.7 Fe22.5 ","(164) V8.3 Ni60.8 Cr16.7 Fe14.2 ","(165) V16.7 Ni60.8 Cr16.7 Fe5.9 ","(166) Ni67.5 Cr18.3 Fe14.2 ","(167) V8.3 Ni67.5 Cr18.3 Fe5.9 ","(168) Ni74.1 Cr20.0 Fe5.9 ","(169) Ni1.6 Cr3.3 Fe95.1 ","(170) V8.3 Ni1.6 Cr3.3 Fe86.7 ","(171) V16.7 Ni1.6 Cr3.3 Fe78.4 ","(178) V75.0 Ni1.6 Cr3.3 Fe20.1 ","(179) V83.3 Ni1.6 Cr3.3 Fe11.7 ","(180) Ni8.3 Cr5.0 Fe86.7 ","(181) V8.3 Ni8.3 Cr5.0 Fe78.4 ","(182) V16.7 Ni8.3 Cr5.0 Fe70.1 ","(183) V25.0 Ni8.3 Cr5.0 Fe61.7 ","(184) V33.3 Ni8.3 Cr5.0 Fe53.4 ","(190) Ni14.9 Cr6.7 Fe78.4 ","(191) V8.3 Ni14.9 Cr6.7 Fe70.1 ","(192) V16.7 Ni14.9 Cr6.7 Fe61.7 ","(193) V25.0 Ni14.9 Cr6.7 Fe53.4 ","(194) V33.3 Ni14.9 Cr6.7 Fe45.1 ","(199) Ni21.6 Cr8.3 Fe70.1 ","(202) V25.0 Ni21.6 Cr8.3 Fe45.1 ","(207) Ni28.3 Cr10.0 Fe61.7 ","(214) Ni34.9 Cr11.7 Fe53.4 ","(220) Ni41.6 Cr13.3 Fe45.1 ","(221) V8.3 Ni41.6 Cr13.3 Fe36.7 ","(225) Ni48.3 Cr15.0 Fe36.7 ","(226) V8.3 Ni48.3 Cr15.0 Fe28.4 ","(229) Ni54.9 Cr16.7 Fe28.4 ","(230) V8.3 Ni54.9 Cr16.7 Fe ...

# %% [markdown]
# ## Path Finding
#
# **Now, let's take the appeal of graph representation a few steps forward! Since they are very general and widely applicable, there are countless off-the-shelf high-performance libraries implementing mathematically optimal path finding algorithms on graphs one can deploy on challenging problems.**
#
# In this example, for the sake of simplicity, we will use pure-Python `pathfinding` library which implements some of the most popular path finding algorithms without high performance (we do not need here) but also without any dependencies. In real applications, you would likely want to use a more advanced library like `networkx` which is more efficient and have more features, or write one yourself. Please note that `nimplex`'s CLI can generate massive graphs in native NumPy format you may find useful for such applications (e.g., to use Julia or C++ libraries).

# %%
from pathfinding.core.graph import Graph
from pathfinding.finder.dijkstra import DijkstraFinder

# %% [markdown]
# Let's now turn our graph definition into a format that `pathfinding` library can understand, assigning equal cost to all edges. **Note, that we only need to consider the feasible points leading to other feasible point!**

# %%
edges = []
for i, nList in enumerate(graphN):
    if gridFeasible[i]:
        for n in nList:
            if gridFeasible[n]:
                edges.append([i, n, 1])
print(edges[:5])
# Out:
# [[0, 1, 1], [1, 0, 1], [1, 2, 1], [2, 1, 1], [2, 3, 1]]

# %% [markdown]
# Let's initialize the `Graph` object.

# %%
pathfindingGraph = Graph(edges=edges, bi_directional=False)

# %% [markdown]
# Now, let's create the `Finder` object that will perform the path finding. Here we use the `DijkstraFinder` which is a very popular algorithm for path finding in graphs (see [it's Wikipedia page](https://en.wikipedia.org/wiki/Dijkstra's_algorithm) for more details). It **finds the shortest possible path between two points in the graph**, which is exactly what we need here. In the future tutorials, we will use some more advanced algorithms, like A*, which accomplishes the same task but in the mathematcally minimal number of evaluations.

# %%
finder = DijkstraFinder()

# %% [markdown]
# For hundreds of points, this shouldn't take more than tenth of a second or so.

# %%
path, runs = finder.find_path(
    pathfindingGraph.node(0), 
    pathfindingGraph.node(90), 
    pathfindingGraph)

# %% [markdown]
# Let's now turn the path into a list of nodes on the path.

# %%
shortestPath = [p.node_id for p in path]

# %% [markdown]
# And plot corresponding compositions. As you can see, we immediately get a neat list of compositions that we can use to design our additive manufacturing path.

# %%
for step, i in enumerate(shortestPath):
    print(f"{step+1:>2}: {formulas[i]}")
# Out:
#  1: (  0) W10.0 Nb10.0 Mo80.0
#  2: (  1) W11.9 Nb11.9 Ta2.8 Mo73.3
#  3: (  2) W13.9 Nb13.9 Ta5.6 Mo66.7
#  4: (  3) W15.8 Nb15.8 Ta8.3 Mo60.0
#  5: (  4) W17.8 Nb17.8 Ta11.1 Mo53.3
#  6: (  5) W19.7 Nb19.7 Ta13.9 Mo46.7
#  7: (  6) W21.7 Nb21.7 Ta16.7 Mo40.0
#  8: (  7) W23.6 Nb23.6 Ta19.4 Mo33.3
#  9: ( 98) Ti4.2 Zr4.2 W22.8 Nb22.8 Ta19.4 Mo26.7
# 10: (110) Ti4.6 Zr4.2 Hf7.9 W21.9 Nb21.9 Ta19.4 Mo20.0
# 11: (121) Ti5.0 Zr4.2 Hf15.8 W21.1 Nb21.1 Ta19.4 Mo13.3
# 12: ( 43) Ti1.2 Hf23.8 W21.1 Nb21.1 Ta19.4 Mo13.3
# 13: ( 53) Ti1.7 Hf31.7 W20.3 Nb20.3 Ta19.4 Mo6.7
# 14: ( 61) Ti2.1 Hf39.6 W17.5 Nb17.5 Ta16.7 Mo6.7
# 15: ( 68) Ti2.5 Hf47.5 W14.7 Nb14.7 Ta13.9 Mo6.7
# 16: ( 74) Ti2.9 Hf55.4 W11.9 Nb11.9 Ta11.1 Mo6.7
# 17: ( 80) Ti3.3 Hf63.3 W11.1 Nb11.1 Ta11.1
# 18: ( 84) Ti3.8 Hf71.2 W8.3 Nb8.3 Ta8.3
# 19: ( 87) Ti4.2 Hf79.2 W5.6 Nb5.6 Ta5.6
# 20: ( 89) Ti4.6 Hf87.1 W2.8 Nb2.8 Ta2.8
# 21: ( 90) Ti5.0 Hf95.0

# %% [markdown]
# **Even better, since we know the positions in the attainable design space, we can get a list of exact quantized instructions (e.g., powder flow rates) for the additive manufacturing apparatus to follow at each step.**
#
# **This is a very powerful abstraction, eliminating possible mistakes and miscommunications between design and manufacturing teams. Furthermore, it also allows for easy manual (or mechanized) per-layer mixing of powders to create compositional paths in single-feed additive manufacturing systems.**

# %%
integerGrid = nimplex.simplex_grid_py(4, 12)
for step, i in enumerate(shortestPath):
    print(f"{step+1:>2}: {integerGrid[i]}")
# Out:
#  1: [0, 0, 0, 12]
#  2: [0, 0, 1, 11]
#  3: [0, 0, 2, 10]
#  4: [0, 0, 3, 9]
#  5: [0, 0, 4, 8]
#  6: [0, 0, 5, 7]
#  7: [0, 0, 6, 6]
#  8: [0, 0, 7, 5]
#  9: [1, 0, 7, 4]
# 10: [1, 1, 7, 3]
# 11: [1, 2, 7, 2]
# 12: [0, 3, 7, 2]
# 13: [0, 4, 7, 1]
# 14: [0, 5, 6, 1]
# 15: [0, 6, 5, 1]
# 16: [0, 7, 4, 1]
# 17: [0, 8, 4, 0]
# 18: [0, 9, 3, 0]
# 19: [0, 10, 2, 0]
# 20: [0, 11, 1, 0]
# 21: [0, 12, 0, 0]

# %% [markdown]
# We can also plot the path in 3D like we did before! As you can see, it **glides through the inside of the tetrahedron in a shortest path** avoiding an obstacle extending far on the face.

# %%
gridFeasibleMarked = ['path' if i in shortestPath else f for i, f in enumerate(gridFeasible)]
fig = px.scatter_3d(gridAtt_projected_df, x='x', y='y', z='z', color=gridFeasibleMarked, text=labels, hover_name=formulas,
              template='plotly_white', width=800, height=700, opacity=0.333, color_discrete_sequence=['blue', 'green', 'red'],
              labels={'color':'Solid Solution Phases', 'x':'', 'y':'', 'z':''})
fig.update_scenes({'camera': {'eye': {'x': -1.8, 'y': 1.2, 'z': 1.5}}})

# %% [markdown]
# ## Path Planning considering the Property Gradient
#
# **Let's go one step further to demonstrate the beaty of the graph representations in the context of efortless path planning in high-dimensional spaces by including the gradient into consideration in just a line or two of code. We will now stretch the space!**

# %%
edges = []
gradientsList = []
penaltyFactor = 100
for i, nList in enumerate(graphN):
    if gridFeasible[i]:
        for n in nList:
            if gridFeasible[n]:
                rmsadGradient = abs(rmsadList[i]-rmsadList[n])
                gradientsList.append(rmsadGradient)
                edges.append([i, n, 1+round(rmsadGradient*penaltyFactor, 3)])
print(edges[:5])
print(f"{len(gradientsList)} gradients calculated with absolute value range between {min(gradientsList)} to {max(gradientsList)}")
print(f"Penalty at {penaltyFactor}x gradient *magnitude* per path step assigned.")
# Out:
# [[0, 1, 1.2770000000000001], [1, 0, 1.2770000000000001], [1, 2, 1.232], [2, 1, 1.232], [2, 3, 1.208]]
# 1386 gradients calculated with absolute value range between 8.898859123501746e-06 to 0.0473823732310002
# Penalty at 100x gradient *magnitude* per path step assigned.

# %% [markdown]
# **As you can see, we just increased the predicted cost of moving between nodes by a small factor ranging from near 0 to 2.5 depending on the RMSAD gradient. In another words, we are prioritizing paths that change RMSAD the least over the entire path.** This can be done, e.g., to minimize the inter-layer stresses in the component caused by yield stress mismatch between the layers that may cause delamination. Similar considerations can also be made for other properties, like thermal expansion coefficient, missmatch of which causes internal stress or wrapping.
#
# **Since the RMSAD is generally smoothly changing, we can expect that this will not impact the result in terms of number of nodes. Just finding a better path of equivalent length. However, if you try to square the gradient by changing penalty to `(rmsadGradient*penaltyFactor)**2`, you will see how viciously the path will avoid any RMSAD changes through zig-zag patterns.**

# %%
pathfindingGraph = Graph(edges=edges, bi_directional=False)
finder = DijkstraFinder()
path, runs = finder.find_path(
    pathfindingGraph.node(0), 
    pathfindingGraph.node(90), 
    pathfindingGraph)
lowGradientPath = [p.node_id for p in path]

# %%
for step, i in enumerate(lowGradientPath):
    print(f"{step+1:>2}: {formulas[i]}")
# Out:
#  1: (  0) W10.0 Nb10.0 Mo80.0
#  2: (  1) W11.9 Nb11.9 Ta2.8 Mo73.3
#  3: (  2) W13.9 Nb13.9 Ta5.6 Mo66.7
#  4: (  3) W15.8 Nb15.8 Ta8.3 Mo60.0
#  5: (  4) W17.8 Nb17.8 Ta11.1 Mo53.3
#  6: (  5) W19.7 Nb19.7 Ta13.9 Mo46.7
#  7: (  6) W21.7 Nb21.7 Ta16.7 Mo40.0
#  8: ( 97) Ti4.2 Zr4.2 W20.8 Nb20.8 Ta16.7 Mo33.3
#  9: (175) Ti8.3 Zr8.3 W20.0 Nb20.0 Ta16.7 Mo26.7
# 10: (186) Ti8.8 Zr8.3 Hf7.9 W19.2 Nb19.2 Ta16.7 Mo20.0
# 11: (196) Ti9.2 Zr8.3 Hf15.8 W18.3 Nb18.3 Ta16.7 Mo13.3
# 12: (205) Ti9.6 Zr8.3 Hf23.8 W17.5 Nb17.5 Ta16.7 Mo6.7
# 13: (139) Ti5.8 Zr4.2 Hf31.7 W17.5 Nb17.5 Ta16.7 Mo6.7
# 14: ( 61) Ti2.1 Hf39.6 W17.5 Nb17.5 Ta16.7 Mo6.7
# 15: ( 68) Ti2.5 Hf47.5 W14.7 Nb14.7 Ta13.9 Mo6.7
# 16: ( 74) Ti2.9 Hf55.4 W11.9 Nb11.9 Ta11.1 Mo6.7
# 17: ( 80) Ti3.3 Hf63.3 W11.1 Nb11.1 Ta11.1
# 18: ( 84) Ti3.8 Hf71.2 W8.3 Nb8.3 Ta8.3
# 19: ( 87) Ti4.2 Hf79.2 W5.6 Nb5.6 Ta5.6
# 20: ( 89) Ti4.6 Hf87.1 W2.8 Nb2.8 Ta2.8
# 21: ( 90) Ti5.0 Hf95.0

# %% [markdown]
# As one can see below, the path still is optimal (21 steps) but it now passes much closer to the center of the tetrahedron, avoiding the lower RMSAD region around `Mo33.3 Nb33.3 Ta33.3` from which it would have to climb a bit more rapidly to reach the `Hf95.0 Zr5.0` point.

# %%
gridFeasibleMarked = ['path' if i in lowGradientPath else f for i, f in enumerate(gridFeasible)]
fig = px.scatter_3d(gridAtt_projected_df, x='x', y='y', z='z', color=gridFeasibleMarked, text=labels, hover_name=formulas,
              template='plotly_white', width=800, height=700, opacity=0.333, color_discrete_sequence=['blue', 'green', 'red'],
              labels={'color':'Solid Solution Phases', 'x':'', 'y':'', 'z':''})
fig.update_scenes({'camera': {'eye': {'x': -1.8, 'y': 1.2, 'z': 1.5}}})

# %% [markdown]
# ## Property Maximization Along the Path
#
# **Finally, let's demonstrate how easy it is to maximize a property along the path by exploiting the unidirectionaliy of the graph edge definitions in `nimplex`, which allow us to efortlessly enocde the property maximization goal as directional reward or penalty applied to edges.** This is as simple as applying the property gradient directly rather than its magnitude.

# %%
edges = []
gradientsList = []
penaltyFactor = 20
for i, nList in enumerate(graphN):
    if gridFeasible[i]:
        for n in nList:
            if gridFeasible[n]:
                rmsadGradient = rmsadList[i]-rmsadList[n]
                gradientsList.append(rmsadGradient)
                edges.append([i, n, 1+round((rmsadGradient*penaltyFactor), 3)])
print(edges[:15])
print(f"{len(gradientsList)} gradients calculated with values up to {max(gradientsList)}")
print(f"Penalty at -{penaltyFactor}x gradient *value* per path step assigned (higher RMSAD preferred)")
# Out:
# [[0, 1, 0.945], [1, 0, 1.055], [1, 2, 0.954], [2, 1, 1.046], [2, 3, 0.958], [3, 2, 1.042], [3, 4, 0.961], [4, 3, 1.039], [4, 5, 0.962], [5, 4, 1.038], [5, 6, 0.963], [6, 5, 1.037], [6, 7, 0.963], [6, 97, 0.577], [7, 6, 1.037]]
# 1386 gradients calculated with values up to 0.0473823732310002
# Penalty at -20x gradient *value* per path step assigned (higher RMSAD preferred)

# %%
pathfindingGraph = Graph(edges=edges, bi_directional=False)
finder = DijkstraFinder()
path, runs = finder.find_path(
    pathfindingGraph.node(0), 
    pathfindingGraph.node(90), 
    pathfindingGraph)
pathList = [p.node_id for p in path]

# %%
for step, i in enumerate(pathList):
    print(f"{step+1:>2}: {formulas[i]}")
# Out:
#  1: (  0) W10.0 Nb10.0 Mo80.0
#  2: (  1) W11.9 Nb11.9 Ta2.8 Mo73.3
#  3: (  2) W13.9 Nb13.9 Ta5.6 Mo66.7
#  4: (  3) W15.8 Nb15.8 Ta8.3 Mo60.0
#  5: (  4) W17.8 Nb17.8 Ta11.1 Mo53.3
#  6: (  5) W19.7 Nb19.7 Ta13.9 Mo46.7
#  7: (  6) W21.7 Nb21.7 Ta16.7 Mo40.0
#  8: ( 97) Ti4.2 Zr4.2 W20.8 Nb20.8 Ta16.7 Mo33.3
#  9: (175) Ti8.3 Zr8.3 W20.0 Nb20.0 Ta16.7 Mo26.7
# 10: (186) Ti8.8 Zr8.3 Hf7.9 W19.2 Nb19.2 Ta16.7 Mo20.0
# 11: (196) Ti9.2 Zr8.3 Hf15.8 W18.3 Nb18.3 Ta16.7 Mo13.3
# 12: (204) Ti9.6 Zr8.3 Hf23.8 W15.6 Nb15.6 Ta13.9 Mo13.3
# 13: (212) Ti10.0 Zr8.3 Hf31.7 W14.7 Nb14.7 Ta13.9 Mo6.7
# 14: (219) Ti10.4 Zr8.3 Hf39.6 W13.9 Nb13.9 Ta13.9
# 15: (153) Ti6.7 Zr4.2 Hf47.5 W13.9 Nb13.9 Ta13.9
# 16: (158) Ti7.1 Zr4.2 Hf55.4 W11.1 Nb11.1 Ta11.1
# 17: (162) Ti7.5 Zr4.2 Hf63.3 W8.3 Nb8.3 Ta8.3
# 18: (165) Ti7.9 Zr4.2 Hf71.2 W5.6 Nb5.6 Ta5.6
# 19: (167) Ti8.3 Zr4.2 Hf79.2 W2.8 Nb2.8 Ta2.8
# 20: (168) Ti8.8 Zr4.2 Hf87.1
# 21: ( 90) Ti5.0 Hf95.0

# %% [markdown]
# **As you can see, we again complete the path in 21 steps but following a different path that maximizes the RMSAD along the way thanks to the small bias we introduced.**

# %%
gridFeasibleMarked = ['path' if i in pathList else f for i, f in enumerate(gridFeasible)]
fig = px.scatter_3d(gridAtt_projected_df, x='x', y='y', z='z', color=gridFeasibleMarked, text=labels, hover_name=formulas,
              template='plotly_white', width=800, height=700, opacity=0.333, color_discrete_sequence=['blue', 'green', 'red'],
              labels={'color':'Solid Solution Phases', 'x':'', 'y':'', 'z':''})
fig.update_scenes({'camera': {'eye': {'x': -1.8, 'y': 1.2, 'z': 1.5}}})

# %% [markdown]
# **And, if we care more about going through high RMSAD regions than we do about the number of steps taken, we can always simply increase the bias to move the path into the high RMSAD regions even more at the cost of the number of steps taken.**

# %%
edges = []
gradientsList = []
penaltyFactor = 200
for i, nList in enumerate(graphN):
    if gridFeasible[i]:
        for n in nList:
            if gridFeasible[n]:
                rmsadGradient = rmsadList[i]-rmsadList[n]
                gradientsList.append(rmsadGradient)
                edges.append([i, n, 1+round((rmsadGradient*penaltyFactor), 3)])
print(edges[:15])
print(f"{len(gradientsList)} gradients calculated with values up to {max(gradientsList)}")
print(f"Penalty at -{penaltyFactor}x gradient *value* per path step assigned (higher RMSAD preferred)")

pathfindingGraph = Graph(edges=edges, bi_directional=False)
finder = DijkstraFinder()
path, runs = finder.find_path(
    pathfindingGraph.node(0), 
    pathfindingGraph.node(90), 
    pathfindingGraph)
pathList = [p.node_id for p in path]
# Out:
# [[0, 1, 0.44599999999999995], [1, 0, 1.554], [1, 2, 0.536], [2, 1, 1.464], [2, 3, 0.5840000000000001], [3, 2, 1.416], [3, 4, 0.609], [4, 3, 1.391], [4, 5, 0.621], [5, 4, 1.379], [5, 6, 0.625], [6, 5, 1.375], [6, 7, 0.626], [6, 97, -3.2300000000000004], [7, 6, 1.374]]
# 1386 gradients calculated with values up to 0.0473823732310002
# Penalty at -200x gradient *value* per path step assigned (higher RMSAD preferred)

# %%
for step, i in enumerate(pathList):
    print(f"{step+1:>2}: {formulas[i]}")
# Out:
#  1: (  0) W10.0 Nb10.0 Mo80.0
#  2: (  1) W11.9 Nb11.9 Ta2.8 Mo73.3
#  3: (  2) W13.9 Nb13.9 Ta5.6 Mo66.7
#  4: (  3) W15.8 Nb15.8 Ta8.3 Mo60.0
#  5: (  4) W17.8 Nb17.8 Ta11.1 Mo53.3
#  6: (  5) W19.7 Nb19.7 Ta13.9 Mo46.7
#  7: (  6) W21.7 Nb21.7 Ta16.7 Mo40.0
#  8: ( 97) Ti4.2 Zr4.2 W20.8 Nb20.8 Ta16.7 Mo33.3
#  9: (175) Ti8.3 Zr8.3 W20.0 Nb20.0 Ta16.7 Mo26.7
# 10: (186) Ti8.8 Zr8.3 Hf7.9 W19.2 Nb19.2 Ta16.7 Mo20.0
# 11: (196) Ti9.2 Zr8.3 Hf15.8 W18.3 Nb18.3 Ta16.7 Mo13.3
# 12: (205) Ti9.6 Zr8.3 Hf23.8 W17.5 Nb17.5 Ta16.7 Mo6.7
# 13: (213) Ti10.0 Zr8.3 Hf31.7 W16.7 Nb16.7 Ta16.7
# 14: (219) Ti10.4 Zr8.3 Hf39.6 W13.9 Nb13.9 Ta13.9
# 15: (279) Ti14.6 Zr12.5 Hf39.6 W11.1 Nb11.1 Ta11.1
# 16: (328) Ti18.8 Zr16.7 Hf39.6 W8.3 Nb8.3 Ta8.3
# 17: (367) Ti22.9 Zr20.8 Hf39.6 W5.6 Nb5.6 Ta5.6
# 18: (369) Ti23.3 Zr20.8 Hf47.5 W2.8 Nb2.8 Ta2.8
# 19: (333) Ti19.6 Zr16.7 Hf55.4 W2.8 Nb2.8 Ta2.8
# 20: (288) Ti15.8 Zr12.5 Hf63.3 W2.8 Nb2.8 Ta2.8
# 21: (233) Ti12.1 Zr8.3 Hf71.2 W2.8 Nb2.8 Ta2.8
# 22: (167) Ti8.3 Zr4.2 Hf79.2 W2.8 Nb2.8 Ta2.8
# 23: (168) Ti8.8 Zr4.2 Hf87.1
# 24: ( 90) Ti5.0 Hf95.0

# %%
gridFeasibleMarked = ['path' if i in pathList else f for i, f in enumerate(gridFeasible)]
fig = px.scatter_3d(gridAtt_projected_df, x='x', y='y', z='z', color=gridFeasibleMarked, text=labels, hover_name=formulas,
              template='plotly_white', width=800, height=700, opacity=0.333, color_discrete_sequence=['blue', 'green', 'red'],
              labels={'color':'Solid Solution Phases', 'x':'', 'y':'', 'z':''})
fig.update_scenes({'camera': {'eye': {'x': -1.8, 'y': 1.2, 'z': 1.5}}})

# %% [markdown]
# ## Final Remarks
#
# **And that's it! We hope you enjoyed this tutorial and that you see the potential of `nimplex` in your work. If you have any questions, feel free to ask them in the `nimplex` repository under the Issues tab. You are also welcome to shoot an email to the author at [adam@phaseslab.org](mailto:adam@phaseslab.org). We will be excited to hear about your applications.**
#
# **We are planning on a couple more tutorials in the future, including a more advanced techniques for more specific use cases within materials science and beyond. PRs with your own tutorials are also welcome!**
